# %% [markdown]
# ### Installation

# %%
try:
    import google.colab
    COLAB = True
    ! pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
except:
    COLAB = False

NEED_DRIVE = True
HAS_DRIVE = False

# %%
if NEED_DRIVE and COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    HAS_DRIVE = True

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "TODO"

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /home/mitchell/dev/hse/RL/venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /home/mitchell/dev/hse/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/home/mitchell/dev/hse/RL/practices/prac7/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = False
if DEMO_WRAPPED_ENV:
    wrapped_env_info()

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # Методы на основе REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# REINFORCE:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# Варианты скор-функции:
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [A_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ### Недостатки
# #### Нестабильное обучение
# - Большой шаг обновления параметров стратегии $\rightarrow$ "плохая" стратегия $\rightarrow$ rollout собирается "плохой" стратегией $\rightarrow$ "плохие" данные $\rightarrow$ обновление стратегии на "плохих" данных $\rightarrow$ ухудшение стратегии
# - Малый размер шага обучения $\rightarrow$ медленное обучение (низкий КПД использования данных)
# - **Малое изменение параметров стратегии не гарантирует, что изменение распределения будет небольшим!**
#
# #### Эффективность использования данных в on-policy режиме (AAC, REINFORCE, ...)
# - Стратегия обновляется по траекториям, которые были получены этой же стратегией, т.е. данные нельзя переиспользовать
# - Обучение нейронной сети требует большого количества итераций обновления параметров, т.е. большого количества эпизодов взаимодействия со средой.
#
# #### Сложности с эффективным применением N-шаговой отдачи с большим N
# - N-шаговая отдача с $N \approx \frac{1}{1 - \gamma}$ может снизить смещение в оценке преимущества $A(s, a)$, при этом дисперсию оценки можно контролировать с помощью параметра $\lambda$ в GAE (General Advantage Estimation)
# - Для эффективного обучения на "длинных" кусках траекторий необходимо разбиение данных на батчи, что противоречит on-policy режиму

# %% [markdown]
# #### Результаты A2C в Atari Pong при увеличении N и количества эпох обучения на собранных данных
# <img src="https://ale.farama.org/_images/pong.gif">

# %% [markdown]
# ![char_a2c](data:image/png;base64,...)

# %% [markdown]
# # 1 Суррогатный функционал оптимизации стратегии
# $$J(\theta) = \mathbb{E}_{(s, a) \sim \pi_{\theta} ^ {old}} \left[ \dfrac{\pi_{\theta}(a|s)}{\pi_{\theta} ^ {old}(a | s)} A(s, a) \right]$$
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
# Реализуем батч-версию алгоритма актор-критик с функцией преимущества и суррогатным функционалом обучения стратегии.

# %% [markdown]
# #### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class Policy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.Adam,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.value_net = nn.Linear(self.features_extractor.features_dim, 1)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))
        log_probs = distribution.log_prob(actions)
        values = self.value_net(features)

        return {'log_prob': log_probs, 'value': values, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()
        values = self.value_net(features)

        return {'log_prob': log_prob, 'value': values, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# #### NStepAdvantageBuffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач и преимущества.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    log_probs: torch.Tensor
    returns: torch.Tensor
    advantages: torch.Tensor


class NStepAdvantageBuffer:
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        self.device = torch.device(device)
        self.gamma = gamma
        self.generator_ready = False
        self.observations = None
        self.actions = None
        self.rewards = None
        self.episode_starts = None
        self.log_probs = None
        self.values = None
        self.returns = None
        self.advantages = None

    def size(self) -> int:
        return len(self.actions)

    def reset(self) -> None:
        self.generator_ready = False
        self.observations = []
        self.actions = []
        self.rewards = []
        self.episode_starts = []
        self.log_probs = []
        self.values = []
        self.returns = None
        self.advantages = None

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
            episode_start: bool,
            log_prob: float,
            value: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)
        self.episode_starts.append(episode_start)
        self.log_probs.append(log_prob)
        self.values.append(value)

    def compute_returns_and_advantage(self, last_value: float, last_terminated: bool) -> None:
        rewards = self.rewards
        episode_starts = self.episode_starts
        values = self.values
        assert len(episode_starts) == len(rewards)
        assert len(values) == len(rewards)

        episode_starts.append(last_terminated)
        values.append(last_value)
        returns = [None] * len(self.rewards)
        advantages = [None] * len(self.rewards)
        reward_to_go = values[-1]
        for step in reversed(range(len(self.rewards))):
            is_next_step_terminal = episode_starts[step + 1]
            reward_to_go = rewards[step] + self.gamma * reward_to_go * (1 - is_next_step_terminal)
            returns[step] = reward_to_go
            advantages[step] = reward_to_go - values[step]

        self.returns = returns
        self.advantages = advantages

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        log_probs = self.to_torch(self.log_probs[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])
        advantages = self.to_torch(self.advantages[batch_inds])

        return BufferSamples(observations=observations, actions=actions, log_probs=log_probs, returns=returns,
                             advantages=advantages)

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.log_probs = np.asarray(self.log_probs, dtype=np.float32)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.advantages = np.asarray(self.advantages, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# #### Surrogate Policy Optimization (2 балла)

# %%
class SPO:
    def __init__(
        self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99,
        ent_coef: float = 0.01, max_grad_norm: float = 0.5, stats_window_size: int = 10,
        policy_class: Type[nn.Module] = Policy, policy_kwargs: Optional[Dict[str, Any]] = {},
        seed: Optional[int] = None, device: Union[torch.device, str] = "cpu",
        buffer_class: Type[NStepAdvantageBuffer] = NStepAdvantageBuffer, buffer_kwargs: Optional[Dict[str, Any]] = {},
        vf_coef: float = 0.5, n_steps: int = 128, batch_size: int = 32,
        n_epochs: int = 1, normalize_advantage: bool = False,
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._last_episode_start = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.gamma = gamma
        self.ent_coef = ent_coef
        self.vf_coef = vf_coef
        self.n_steps = n_steps
        self.batch_size = batch_size
        self.n_epochs = n_epochs
        self.normalize_advantage = normalize_advantage
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy_kwargs = policy_kwargs
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        entropy_losses = []
        entropies = []
        pg_losses = []
        value_losses = []
        losses = []
        grad_norms = []
        log_ratios = {}
        log_fractions = {}

        for epoch in range(self.n_epochs):
            log_ratios[epoch] = []
            log_fractions[epoch] = {0.05: [], 0.10: [], 0.20: []}
            for rollout_data in self.buffer.get(self.batch_size):
                actions = rollout_data.actions.long()
                policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']
                values = policy_output['value']
                advantages = rollout_data.advantages
                if self.normalize_advantage and len(advantages) > 1:
                    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

                # Policy loss
                old_log_prob = rollout_data.log_probs
                ratio = torch.exp(log_prob - old_log_prob)
                policy_loss = -(ratio * advantages).mean()

                # Logging policy loss
                pg_losses.append(policy_loss.item())

                # Логируем степень изменения стратегии
                log_ratios[epoch].append(ratio.mean().item())
                for log_range in log_fractions[epoch]:
                    fraction = torch.mean((torch.abs(ratio - 1) > log_range).float()).item()
                    log_fractions[epoch][log_range].append(fraction)

                # Entropy loss
                entropy = torch.mean(entropy)
                entropy_loss = -self.ent_coef * entropy
                entropies.append(entropy.item())
                entropy_losses.append(entropy_loss.item())

                # Value loss
                value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns.reshape_as(values))
                value_losses.append(value_loss.item())

                loss = policy_loss + entropy_loss + value_loss
                losses.append(loss.item())

                # Optimization step
                self.policy.optimizer.zero_grad()
                loss.backward()
                grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
                grad_norms.append(grad_norm.item())
                self.policy.optimizer.step()

            self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", np.mean(entropy_losses)), ("train/entropy", np.mean(entropies)),
            ("train/policy_gradient_loss", np.mean(pg_losses)), ("train/loss", np.mean(losses)),
            ("train/grad_norm", np.mean(grad_norms)), ("train/n_updates", self._n_updates),
            ("train/value_loss", np.mean(value_losses)),
        ])

        for epoch in log_ratios.keys():
            self.log_dict[f"train/ratio_epoch-{epoch}"] = np.mean(log_ratios[epoch])

        for epoch in log_fractions.keys():
            for ration_range in log_fractions[epoch]:
                self.log_dict[f"train/fraction-{ration_range}_epoch-{epoch}"] = np.mean(log_fractions[epoch][ration_range])

    def collect_rollouts(
            self,
            env,
            buffer: NStepAdvantageBuffer,
    ):
        self.policy.set_training_mode(False)
        assert self._last_obs is not None, "No previous observation was provided"
        self._last_obs = np.array(self._last_obs)

        step = 0
        buffer.reset()
        while step < self.batch_size:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                policy_output = self.policy(obs_tensor.unsqueeze(0))
                action = policy_output['action'].item()
                value = policy_output['value'].item()
                log_prob = policy_output['log_prob'].item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'We do not handle truncation by episode time_limit for simplicity'

            step += 1
            self.num_timesteps += 1
            self._episode_num += int(terminated)
            # Сохранить данные в буфер: наблюдение, действие, награда, флаг начала эпизода, полезность
            buffer.add(
                self._last_obs,
                action,
                reward,
                self._last_episode_start,
                log_prob,
                value,
            )

            self._update_info_buffer(info)
            # Обработка флага terminated: при завершении эпизода вызываем env.reset()
            self._last_episode_start = terminated
            if terminated:
                self._last_obs, _ = env.reset()
            else:
                self._last_obs = new_obs

            self._last_obs = np.asarray(self._last_obs)


        # Вычисление отдач в буфере: buffer.computer_returns(...)
        last_value = self.policy(torch.as_tensor(np.array(new_obs), device=self.device).unsqueeze(0))['value'].item()
        buffer.compute_returns_and_advantage(last_value=last_value, last_terminated=terminated)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        next_log_step = self.num_timesteps + log_interval

        if save_checkpoint_interval is None or save_checkpoint_path is None:
            save_checkpoint_interval = math.inf

        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)
            self._last_episode_start = True

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer,)
            iteration += 1

            if self.num_timesteps >= next_log_step:
                next_log_step += log_interval
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=SPO,
    algorithm_kwargs=dict(seed=0, normalize_advantage=False, n_epochs=1,),
    use_wandb=False,
    wandb_kwargs=dict(project='seminar_ppo', monitor_gym=True, name='SPO', mode='offline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000,
                      save_checkpoint_path='./1_spo',
                      save_checkpoint_interval=1000)
)
# Out:
# Using cpu device
# /tmp/ipykernel_61194/3539175664.py:152: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_61194/3539175664.py:191: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   last_value = self.policy(torch.as_tensor(np.array(new_obs), device=self.device).unsqueeze(0))['value'].item()
# {
#     "global_step": 1024,
#     "num_episodes": 2,
#     "rollout/ep_len_mean": 402.5,
#     "rollout/ep_rew_mean": -111.03118896484375,
#     "time/fps": 82,
#     "time/iterations": 32,
#     "time/time_elapsed": 12,
#     "train/entropy": 2.078707218170166,
#     "train/entropy_loss": -0.0207870714366436,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.103608138859272,
#     "train/loss": -0.1012498214840889,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": -0.08490148186683655,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.004438735544681549
# }
# {
#     "global_step": 2016,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 380.3333333333333,
#     "rollout/ep_rew_mean": -101.26880645751953,
#     "time/fps": 82,
#     "time/iterations": 63,
#     "time/time_elapsed": 24,
#     "train/entropy": 2.066070079803467,
#     "train/entropy_loss": -0.020660700276494026,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.2588635981082916,
#     "train/loss": -0.14734649658203125,
#     "train/n_updates": 62,
#     "train/policy_gradient_loss": -0.13839755952358246,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.011711768805980682
# }
# {
#     "global_step": 3008,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 372.75,
#     "rollout/ep_rew_mean": 214.1444854736328,
#     "time/fps": 82,
#     "time/iterations": 94,
#     "time/time_elapsed": 36,
#     "train/entropy": 0.16588513553142548,
#     "train/entropy_loss": -0.0016588512808084488,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 13.05302906036377,
#     "train/loss": -0.2335241138935089,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": -0.2898521423339844,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.05798687785863876
# }
# {
#     "global_step": 4000,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 188.5,
#     "rollout/ep_rew_mean": 859.22265625,
#     "time/fps": 89,
#     "time/iterations": 125,
#     "time/time_elapsed": 44,
#     "train/entropy": 0.27017390727996826,
#     "train/entropy_loss": -0.0027017390821129084,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.7892141342163086,
#     "train/loss": -0.03769780322909355,
#     "train/n_updates": 124,
#     "train/policy_gradient_loss": -0.04143739119172096,
#     "train/ratio_epoch-0": 0.9999999403953552,
#     "train/value_loss": 0.00644132774323225
# }
# {
#     "global_step": 5024,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 167.2,
#     "rollout/ep_rew_mean": 1705.441650390625,
#     "time/fps": 92,
#     "time/iterations": 157,
#     "time/time_elapsed": 54,
#     "train/entropy": 0.2292710691690445,
#     "train/entropy_loss": -0.0022927105892449617,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 41.161373138427734,
#     "train/loss": 1.0100114345550537,
#     "train/n_updates": 156,
#     "train/policy_gradient_loss": -0.6919153928756714,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 1.7042194604873657
# }
# {
#     "global_step": 6016,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 160.1,
#     "rollout/ep_rew_mean": 1437.07275390625,
#     "time/fps": 95,
#     "time/iterations": 188,
#     "time/time_elapsed": 62,
#     "train/entropy": 0.485991895198822,
#     "train/entropy_loss": -0.004859918728470802,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.4043984413146973,
#     "train/loss": -0.0120171457529068,
#     "train/n_updates": 187,
#     "train/policy_gradient_loss": -0.0750911608338356,
#     "train/ratio_epoch-0": 0.9999998807907104,
#     "train/value_loss": 0.06793393194675446
# }
# {
#     "global_step": 7008,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 169.5,
#     "rollout/ep_rew_mean": 854.0848388671875,
#     "time/fps": 100,
#     "time/iterations": 219,
#     "time/time_elapsed": 69,
#     "train/entropy": 1.265230417251587,
#     "train/entropy_loss": -0.012652304023504257,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 38.84296417236328,
#     "train/loss": 4.480595588684082,
#     "train/n_updates": 218,
#     "train/policy_gradient_loss": 1.7406073808670044,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 2.752640724182129
# }
# {
#     "global_step": 8000,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 173.8,
#     "rollout/ep_rew_mean": 743.4072265625,
#     "time/fps": 103,
#     "time/iterations": 250,
#     "time/time_elapsed": 77,
#     "train/entropy": 0.31814509630203247,
#     "train/entropy_loss": -0.0031814510002732277,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.3262720108032227,
#     "train/loss": 0.0924910306930542,
#     "train/n_updates": 249,
#     "train/policy_gradient_loss": 0.04865914583206177,
#     "train/ratio_epoch-0": 1.0000001192092896,
#     "train/value_loss": 0.047013334929943085
# }
# {
#     "global_step": 9024,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 149.9,
#     "rollout/ep_rew_mean": 942.9088134765625,
#     "time/fps": 105,
#     "time/iterations": 282,
#     "time/time_elapsed": 85,
#     "train/entropy": 0.34858518838882446,
#     "train/entropy_loss": -0.0034858519211411476,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 207.78652954101562,
#     "train/loss": 19.06121826171875,
#     "train/n_updates": 281,
#     "train/policy_gradient_loss": 4.809716701507568,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 14.254987716674805
# }
# {
#     "global_step": 10016,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 155.0,
#     "rollout/ep_rew_mean": 1093.695068359375,
#     "time/fps": 107,
#     "time/iterations": 313,
#     "time/time_elapsed": 93,
#     "train/entropy": 0.2549401819705963,
#     "train/entropy_loss": -0.00254940171726048,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 6.2880096435546875,
#     "train/loss": 0.16111987829208374,
#     "train/n_updates": 312,
#     "train/policy_gradient_loss": 0.09901037812232971,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.06465889513492584
# }
# {
#     "global_step": 11008,
#     "num_episodes": 57,
#     "rollout/ep_len_mean": 157.8,
#     "rollout/ep_rew_mean": 1274.473876953125,
#     "time/fps": 107,
#     "time/iterations": 344,
#     "time/time_elapsed": 102,
#     "train/entropy": 0.6527648568153381,
#     "train/entropy_loss": -0.0065276483073830605,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 22.390029907226562,
#     "train/loss": -0.3997143507003784,
#     "train/n_updates": 343,
#     "train/policy_gradient_loss": -0.6379585266113281,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.2447718381881714
# }
# {
#     "global_step": 12000,
#     "num_episodes": 63,
#     "rollout/ep_len_mean": 163.2,
#     "rollout/ep_rew_mean": 1109.507080078125,
#     "time/fps": 108,
#     "time/iterations": 375,
#     "time/time_elapsed": 110,
#     "train/entropy": 0.9947277307510376,
#     "train/entropy_loss": -0.009947276674211025,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 2.6007637977600098,
#     "train/loss": -0.07451286911964417,
#     "train/n_updates": 374,
#     "train/policy_gradient_loss": -0.07955446094274521,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.014988873153924942
# }
# {
#     "global_step": 13024,
#     "num_episodes": 67,
#     "rollout/ep_len_mean": 172.6,
#     "rollout/ep_rew_mean": 854.65625,
#     "time/fps": 110,
#     "time/iterations": 407,
#     "time/time_elapsed": 118,
#     "train/entropy": 2.077341079711914,
#     "train/entropy_loss": -0.02077341079711914,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.021421052515506744,
#     "train/loss": -0.01575440727174282,
#     "train/n_updates": 406,
#     "train/policy_gradient_loss": 0.003817347576841712,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.0012016560649499297
# }
# {
#     "global_step": 14016,
#     "num_episodes": 71,
#     "rollout/ep_len_mean": 229.3,
#     "rollout/ep_rew_mean": 432.8677673339844,
#     "time/fps": 112,
#     "time/iterations": 438,
#     "time/time_elapsed": 124,
#     "train/entropy": 0.6879820823669434,
#     "train/entropy_loss": -0.006879820488393307,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.387546062469482,
#     "train/loss": 0.12501998245716095,
#     "train/n_updates": 437,
#     "train/policy_gradient_loss": 0.12141439318656921,
#     "train/ratio_epoch-0": 1.000000238418579,
#     "train/value_loss": 0.01048540510237217
# }
# {
#     "global_step": 15008,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 246.4,
#     "rollout/ep_rew_mean": 1054.536865234375,
#     "time/fps": 111,
#     "time/iterations": 469,
#     "time/time_elapsed": 134,
#     "train/entropy": 0.4633874297142029,
#     "train/entropy_loss": -0.004633874166756868,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 20.671310424804688,
#     "train/loss": 0.422601580619812,
#     "train/n_updates": 468,
#     "train/policy_gradient_loss": 0.3165913224220276,
#     "train/ratio_epoch-0": 0.9999998211860657,
#     "train/value_loss": 0.11064413189888
# }
# {
#     "global_step": 16000,
#     "num_episodes": 82,
#     "rollout/ep_len_mean": 189.2,
#     "rollout/ep_rew_mean": 2022.523193359375,
#     "time/fps": 110,
#     "time/iterations": 500,
#     "time/time_elapsed": 144,
#     "train/entropy": 0.31327110528945923,
#     "train/entropy_loss": -0.0031327109318226576,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.852370738983154,
#     "train/loss": -0.09221656620502472,
#     "train/n_updates": 499,
#     "train/policy_gradient_loss": -0.1546754688024521,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.06559161841869354
# }
# Решено!

# %% [markdown]
# # 2 Proximal Policy Optimization
# Как гарантировать, что обновление стратегии не приведёт к большим изменениям?
#
# В практической реализации существует два варианта реализации алгоритма PPO:
# * Penalty: выполняет обновление, ограниченное KL-дивергенцией, как TRPO, но штрафует KL-дивергенцией в целевой функции вместо того, чтобы делать его жестким ограничением, и автоматически регулирует коэффициент штрафа в процессе обучения, чтобы он масштабировался соответствующим образом.
# * Clip: более простой вариант, не содержит в целевой функции члена KL-дивергенции и вообще не имеет ограничения, но полагается на специализированный клиппинг. Параметр $\epsilon$ называется `clip_range`.
#
# <img src="https://spinningup.openai.com/en/latest/_images/math/e62a8971472597f4b014c2da064f636ffe365ba3.svg">
# <br><br>
# <img src="https://spinningup.openai.com/en/latest/_images/math/39f524858866b80e627840ba77a54360e3bac55e.svg">
#
# <br><br>

# %% [markdown]
# ![char_a2c](data:image/png;base64,...)

# %% [markdown]
# #### Как отношение вероятностей обновлённой и старой стратегии коррелирует со стабильностью обучения?
# Визаулизация степени изменения стратегии во время обучения:
# - **A2C**: https://wandb.ai/ula_elfray/a2c_PongNoFrameskip-v4/reports/A2C-Atari-Pong---VmlldzoxMTczNzEwNw

# %% [markdown]
# (2 балла)

# %%
class PPO(SPO):
    def __init__(
        self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99,
        ent_coef: float = 0.01, max_grad_norm: float = 0.5, stats_window_size: int = 10,
        policy_class: Type[nn.Module] = Policy, policy_kwargs: Optional[Dict[str, Any]] = {},
        seed: Optional[int] = None, device: Union[torch.device, str] = "cpu",
        buffer_class: Type[NStepAdvantageBuffer] = NStepAdvantageBuffer, buffer_kwargs: Optional[Dict[str, Any]] = {},
        vf_coef: float = 0.5, n_steps: int = 128, batch_size: int = 32,
        n_epochs: int = 1, normalize_advantage: bool = False,
        clip_range: float = math.inf,
    ):
        super().__init__(
            env, learning_rate, gamma,
            ent_coef, max_grad_norm, stats_window_size,
            policy_class, policy_kwargs, seed,
            device, buffer_class, buffer_kwargs, vf_coef, n_steps,
            batch_size, n_epochs, normalize_advantage,
        )
        self.clip_range = clip_range

    def train(self) -> None:
        self.policy.set_training_mode(True)

        entropy_losses = []
        entropies = []
        pg_losses = []
        value_losses = []
        losses = []
        grad_norms = []
        clip_fractions = []
        log_ratios = {}
        log_fractions = {}

        for epoch in range(self.n_epochs):
            log_ratios[epoch] = []
            log_fractions[epoch] = {0.05: [], 0.10: [], 0.20: []}
            for rollout_data in self.buffer.get(self.batch_size):
                actions = rollout_data.actions.long()
                policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']
                values = policy_output['value']
                advantages = rollout_data.advantages
                if self.normalize_advantage and len(advantages) > 1:
                    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

                # Policy loss
                old_log_prob = rollout_data.log_probs
                ratio = torch.exp(log_prob - old_log_prob)
                policy_loss_1 = advantages * ratio
                policy_loss_2 = advantages * torch.clamp(ratio, 1 - self.clip_range, 1 + self.clip_range)
                policy_loss = -torch.min(policy_loss_1, policy_loss_2).mean()

                # Logging policy loss
                pg_losses.append(policy_loss.item())
                # Логируем долю состояний, в которых сработало клиппирование
                clip_fraction = torch.mean((torch.abs(ratio - 1) > self.clip_range).float()).item()
                clip_fractions.append(clip_fraction)

                # Логируем степень изменения стратегии
                log_ratios[epoch].append(ratio.mean().item())
                for log_range in log_fractions[epoch]:
                    fraction = torch.mean((torch.abs(ratio - 1) > log_range).float()).item()
                    log_fractions[epoch][log_range].append(fraction)

                # Entropy loss
                entropy = torch.mean(entropy)
                entropy_loss = -self.ent_coef * entropy
                entropies.append(entropy.item())
                entropy_losses.append(entropy_loss.item())

                # Value loss
                value_loss = self.vf_coef * F.mse_loss(values, rollout_data.returns.reshape_as(values))
                value_losses.append(value_loss.item())

                loss = policy_loss + entropy_loss + value_loss
                losses.append(loss.item())

                # Optimization step
                self.policy.optimizer.zero_grad()
                loss.backward()
                grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
                grad_norms.append(grad_norm.item())
                self.policy.optimizer.step()

            self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", np.mean(entropy_losses)), ("train/entropy", np.mean(entropies)),
            ("train/policy_gradient_loss", np.mean(pg_losses)), ("train/loss", np.mean(losses)),
            ("train/grad_norm", np.mean(grad_norms)), ("train/n_updates", self._n_updates),
            ("train/value_loss", np.mean(value_losses)), ("train/clip_fraction", np.mean(clip_fractions)),
            ("train/clip_range", self.clip_range),
        ])

        for epoch in log_ratios.keys():
            self.log_dict[f"train/ratio_epoch-{epoch}"] = np.mean(log_ratios[epoch])

        for epoch in log_fractions.keys():
            for ration_range in log_fractions[epoch]:
                self.log_dict[f"train/fraction-{ration_range}_epoch-{epoch}"] = np.mean(log_fractions[epoch][ration_range])

# %%
run_algorithm(
    algorithm_class=PPO,
    algorithm_kwargs=dict(seed=0, normalize_advantage=False, n_epochs=1, clip_range=0.1),
    use_wandb=False,
    wandb_kwargs=dict(project='seminar_ppo', monitor_gym=True, name='PPO', mode='offline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000,
                      save_checkpoint_path='./2_ppo',
                      save_checkpoint_interval=1000)
)
# Out:
# /home/mitchell/dev/hse/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cpu device
# /tmp/ipykernel_61194/3539175664.py:152: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_61194/3539175664.py:191: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   last_value = self.policy(torch.as_tensor(np.array(new_obs), device=self.device).unsqueeze(0))['value'].item()
# {
#     "global_step": 1024,
#     "num_episodes": 2,
#     "rollout/ep_len_mean": 402.5,
#     "rollout/ep_rew_mean": -111.03118896484375,
#     "time/fps": 155,
#     "time/iterations": 32,
#     "time/time_elapsed": 6,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 2.078707218170166,
#     "train/entropy_loss": -0.0207870714366436,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.103608138859272,
#     "train/loss": -0.1012498214840889,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": -0.08490148186683655,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.004438735544681549
# }
# {
#     "global_step": 2016,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 380.3333333333333,
#     "rollout/ep_rew_mean": -101.26880645751953,
#     "time/fps": 164,
#     "time/iterations": 63,
#     "time/time_elapsed": 12,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 2.066070079803467,
#     "train/entropy_loss": -0.020660700276494026,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.2588635981082916,
#     "train/loss": -0.14734649658203125,
#     "train/n_updates": 62,
#     "train/policy_gradient_loss": -0.13839755952358246,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.011711768805980682
# }
# {
#     "global_step": 3008,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 372.75,
#     "rollout/ep_rew_mean": 214.1444854736328,
#     "time/fps": 167,
#     "time/iterations": 94,
#     "time/time_elapsed": 17,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.16588513553142548,
#     "train/entropy_loss": -0.0016588512808084488,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 13.05302906036377,
#     "train/loss": -0.2335241138935089,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": -0.2898521423339844,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.05798687785863876
# }
# {
#     "global_step": 4000,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 188.5,
#     "rollout/ep_rew_mean": 859.22265625,
#     "time/fps": 148,
#     "time/iterations": 125,
#     "time/time_elapsed": 26,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.27017390727996826,
#     "train/entropy_loss": -0.0027017390821129084,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.7892141342163086,
#     "train/loss": -0.03769780322909355,
#     "train/n_updates": 124,
#     "train/policy_gradient_loss": -0.04143739119172096,
#     "train/ratio_epoch-0": 0.9999999403953552,
#     "train/value_loss": 0.00644132774323225
# }
# {
#     "global_step": 5024,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 167.2,
#     "rollout/ep_rew_mean": 1705.441650390625,
#     "time/fps": 154,
#     "time/iterations": 157,
#     "time/time_elapsed": 32,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.2292710691690445,
#     "train/entropy_loss": -0.0022927105892449617,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 41.161373138427734,
#     "train/loss": 1.0100114345550537,
#     "train/n_updates": 156,
#     "train/policy_gradient_loss": -0.6919153928756714,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 1.7042194604873657
# }
# {
#     "global_step": 6016,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 160.1,
#     "rollout/ep_rew_mean": 1437.07275390625,
#     "time/fps": 161,
#     "time/iterations": 188,
#     "time/time_elapsed": 37,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.485991895198822,
#     "train/entropy_loss": -0.004859918728470802,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.4043984413146973,
#     "train/loss": -0.0120171457529068,
#     "train/n_updates": 187,
#     "train/policy_gradient_loss": -0.0750911608338356,
#     "train/ratio_epoch-0": 0.9999998807907104,
#     "train/value_loss": 0.06793393194675446
# }
# {
#     "global_step": 7008,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 169.5,
#     "rollout/ep_rew_mean": 854.0848388671875,
#     "time/fps": 163,
#     "time/iterations": 219,
#     "time/time_elapsed": 42,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.265230417251587,
#     "train/entropy_loss": -0.012652304023504257,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 38.84296417236328,
#     "train/loss": 4.480595588684082,
#     "train/n_updates": 218,
#     "train/policy_gradient_loss": 1.7406073808670044,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 2.752640724182129
# }
# {
#     "global_step": 8000,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 173.8,
#     "rollout/ep_rew_mean": 743.4072265625,
#     "time/fps": 163,
#     "time/iterations": 250,
#     "time/time_elapsed": 49,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.31814509630203247,
#     "train/entropy_loss": -0.0031814510002732277,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.3262720108032227,
#     "train/loss": 0.0924910306930542,
#     "train/n_updates": 249,
#     "train/policy_gradient_loss": 0.04865914583206177,
#     "train/ratio_epoch-0": 1.0000001192092896,
#     "train/value_loss": 0.047013334929943085
# }
# {
#     "global_step": 9024,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 149.9,
#     "rollout/ep_rew_mean": 942.9088134765625,
#     "time/fps": 162,
#     "time/iterations": 282,
#     "time/time_elapsed": 55,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.34858518838882446,
#     "train/entropy_loss": -0.0034858519211411476,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 207.78652954101562,
#     "train/loss": 19.06121826171875,
#     "train/n_updates": 281,
#     "train/policy_gradient_loss": 4.809716701507568,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 14.254987716674805
# }
# {
#     "global_step": 10016,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 155.0,
#     "rollout/ep_rew_mean": 1093.695068359375,
#     "time/fps": 168,
#     "time/iterations": 313,
#     "time/time_elapsed": 59,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.2549401819705963,
#     "train/entropy_loss": -0.00254940171726048,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 6.2880096435546875,
#     "train/loss": 0.16111987829208374,
#     "train/n_updates": 312,
#     "train/policy_gradient_loss": 0.09901037812232971,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.06465889513492584
# }
# {
#     "global_step": 11008,
#     "num_episodes": 57,
#     "rollout/ep_len_mean": 157.8,
#     "rollout/ep_rew_mean": 1274.473876953125,
#     "time/fps": 164,
#     "time/iterations": 344,
#     "time/time_elapsed": 66,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6527648568153381,
#     "train/entropy_loss": -0.0065276483073830605,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 22.390029907226562,
#     "train/loss": -0.3997143507003784,
#     "train/n_updates": 343,
#     "train/policy_gradient_loss": -0.6379585266113281,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.2447718381881714
# }
# {
#     "global_step": 12000,
#     "num_episodes": 63,
#     "rollout/ep_len_mean": 163.2,
#     "rollout/ep_rew_mean": 1109.507080078125,
#     "time/fps": 162,
#     "time/iterations": 375,
#     "time/time_elapsed": 73,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.9947277307510376,
#     "train/entropy_loss": -0.009947276674211025,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 2.6007637977600098,
#     "train/loss": -0.07451286911964417,
#     "train/n_updates": 374,
#     "train/policy_gradient_loss": -0.07955446094274521,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.014988873153924942
# }
# {
#     "global_step": 13024,
#     "num_episodes": 67,
#     "rollout/ep_len_mean": 172.6,
#     "rollout/ep_rew_mean": 854.65625,
#     "time/fps": 165,
#     "time/iterations": 407,
#     "time/time_elapsed": 78,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 2.077341079711914,
#     "train/entropy_loss": -0.02077341079711914,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.021421052515506744,
#     "train/loss": -0.01575440727174282,
#     "train/n_updates": 406,
#     "train/policy_gradient_loss": 0.003817347576841712,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.0012016560649499297
# }
# {
#     "global_step": 14016,
#     "num_episodes": 71,
#     "rollout/ep_len_mean": 229.3,
#     "rollout/ep_rew_mean": 432.8677673339844,
#     "time/fps": 170,
#     "time/iterations": 438,
#     "time/time_elapsed": 82,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6879820823669434,
#     "train/entropy_loss": -0.006879820488393307,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.387546062469482,
#     "train/loss": 0.12501998245716095,
#     "train/n_updates": 437,
#     "train/policy_gradient_loss": 0.12141439318656921,
#     "train/ratio_epoch-0": 1.000000238418579,
#     "train/value_loss": 0.01048540510237217
# }
# {
#     "global_step": 15008,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 246.4,
#     "rollout/ep_rew_mean": 1054.536865234375,
#     "time/fps": 171,
#     "time/iterations": 469,
#     "time/time_elapsed": 87,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.4633874297142029,
#     "train/entropy_loss": -0.004633874166756868,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 20.671310424804688,
#     "train/loss": 0.422601580619812,
#     "train/n_updates": 468,
#     "train/policy_gradient_loss": 0.3165913224220276,
#     "train/ratio_epoch-0": 0.9999998211860657,
#     "train/value_loss": 0.11064413189888
# }
# {
#     "global_step": 16000,
#     "num_episodes": 82,
#     "rollout/ep_len_mean": 189.2,
#     "rollout/ep_rew_mean": 2022.523193359375,
#     "time/fps": 170,
#     "time/iterations": 500,
#     "time/time_elapsed": 94,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.31327110528945923,
#     "train/entropy_loss": -0.0031327109318226576,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.852370738983154,
#     "train/loss": -0.09221656620502472,
#     "train/n_updates": 499,
#     "train/policy_gradient_loss": -0.1546754688024521,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.06559161841869354
# }
# Решено!

# %% [markdown]
# ### Влияние параметров и реализации на производительность PPO:
# Спойлер: клиппинг - не самое главное в PPO, как это могло показаться на первый взгляд. Алгоритм PPO работает во многом и за счет небольших дополнительных улучшений. Подробнее:
# - https://arxiv.org/abs/2005.12729
# - https://arxiv.org/abs/2006.05990
# - https://iclr-blog-track.github.io/2022/03/25/ppo-implementation-details/

# %% [markdown]
# # 3 Раздельные features extractor для актора и критика

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %% [markdown]
# (4 балла)

# %%
class PolicySeparateFeaturesExtractors(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.Adam,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        # Отдельные features_extractor для актора и критика
        self.actor_features_extractor = self.make_features_extractor()
        self.value_features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.actor_features_extractor.features_dim, self.action_space.n)
        self.value_net = nn.Linear(self.value_features_extractor.features_dim, 1)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        actor_features = self.actor_features_extractor(obs)
        value_features = self.value_features_extractor(obs)

        return actor_features, value_features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        actor_features, value_features = self.extract_features(obs)
        action_logits = self.action_net(actor_features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))
        log_probs = distribution.log_prob(actions)
        values = self.value_net(value_features)

        return {'log_prob': log_probs, 'value': values, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        actor_features, value_features = self.extract_features(obs)
        action_logits = self.action_net(actor_features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()
        values = self.value_net(value_features)

        return {'log_prob': log_prob, 'value': values, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %%
run_algorithm(
    algorithm_class=PPO,
    algorithm_kwargs=dict(seed=0, normalize_advantage=False, n_epochs=1, clip_range=0.1, policy_class=PolicySeparateFeaturesExtractors),
    use_wandb=False,
    wandb_kwargs=dict(project='seminar_ppo', monitor_gym=True, name='PPO-non-shared', mode='offline'),
    learn_kwargs=dict(max_timesteps=100000, log_interval=1000, expected_return=2000,
                      save_checkpoint_path='./3_ppo-non-shared',
                      save_checkpoint_interval=1000)
)
# Out:
# Using cpu device
# /tmp/ipykernel_61194/3539175664.py:152: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_61194/3539175664.py:191: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   last_value = self.policy(torch.as_tensor(np.array(new_obs), device=self.device).unsqueeze(0))['value'].item()
# {
#     "global_step": 1024,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 325.6666666666667,
#     "rollout/ep_rew_mean": 44.16835021972656,
#     "time/fps": 115,
#     "time/iterations": 32,
#     "time/time_elapsed": 8,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.5191121101379395,
#     "train/entropy_loss": -0.015191121026873589,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.0378698110580444,
#     "train/loss": 0.2553749680519104,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 0.19841444492340088,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.07215164601802826
# }
# {
#     "global_step": 2016,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 330.6666666666667,
#     "rollout/ep_rew_mean": 289.1856689453125,
#     "time/fps": 123,
#     "time/iterations": 63,
#     "time/time_elapsed": 16,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.6853830814361572,
#     "train/entropy_loss": -0.016853829845786095,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 26.504383087158203,
#     "train/loss": 4.70161247253418,
#     "train/n_updates": 62,
#     "train/policy_gradient_loss": 2.2258682250976562,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 2.492597818374634
# }
# {
#     "global_step": 3008,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 308.22222222222223,
#     "rollout/ep_rew_mean": 312.1631164550781,
#     "time/fps": 126,
#     "time/iterations": 94,
#     "time/time_elapsed": 23,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.192883014678955,
#     "train/entropy_loss": -0.011928830295801163,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.4584096670150757,
#     "train/loss": 0.07774128764867783,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": 0.07971253246068954,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.009957586415112019
# }
# {
#     "global_step": 4000,
#     "num_episodes": 14,
#     "rollout/ep_len_mean": 249.5,
#     "rollout/ep_rew_mean": 543.5278930664062,
#     "time/fps": 128,
#     "time/iterations": 125,
#     "time/time_elapsed": 31,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.8829552531242371,
#     "train/entropy_loss": -0.008829552680253983,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 19.718591690063477,
#     "train/loss": -0.4439143240451813,
#     "train/n_updates": 124,
#     "train/policy_gradient_loss": -0.756523609161377,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.32143881916999817
# }
# {
#     "global_step": 5024,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 177.8,
#     "rollout/ep_rew_mean": 679.87548828125,
#     "time/fps": 126,
#     "time/iterations": 157,
#     "time/time_elapsed": 39,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.7320665121078491,
#     "train/entropy_loss": -0.007320664823055267,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.21855354309082,
#     "train/loss": -0.19047747552394867,
#     "train/n_updates": 156,
#     "train/policy_gradient_loss": -0.21922892332077026,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.03607211634516716
# }
# {
#     "global_step": 6016,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 161.0,
#     "rollout/ep_rew_mean": 637.2471923828125,
#     "time/fps": 132,
#     "time/iterations": 188,
#     "time/time_elapsed": 45,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.43509620428085327,
#     "train/entropy_loss": -0.004350962117314339,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 11.486949920654297,
#     "train/loss": -0.28167223930358887,
#     "train/n_updates": 187,
#     "train/policy_gradient_loss": -0.35183829069137573,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.07451701909303665
# }
# {
#     "global_step": 7008,
#     "num_episodes": 31,
#     "rollout/ep_len_mean": 168.0,
#     "rollout/ep_rew_mean": 959.6668090820312,
#     "time/fps": 130,
#     "time/iterations": 219,
#     "time/time_elapsed": 53,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.3848460912704468,
#     "train/entropy_loss": -0.013848460279405117,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.7777430415153503,
#     "train/loss": -0.046613339334726334,
#     "train/n_updates": 218,
#     "train/policy_gradient_loss": -0.04007957503199577,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.007314697839319706
# }
# {
#     "global_step": 8000,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 225.1,
#     "rollout/ep_rew_mean": 982.3391723632812,
#     "time/fps": 128,
#     "time/iterations": 250,
#     "time/time_elapsed": 62,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.821969211101532,
#     "train/entropy_loss": -0.008219691924750805,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 8.142410278320312,
#     "train/loss": -0.35381850600242615,
#     "train/n_updates": 249,
#     "train/policy_gradient_loss": -0.5000742077827454,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.15447542071342468
# }
# {
#     "global_step": 9024,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 228.3,
#     "rollout/ep_rew_mean": 1032.689453125,
#     "time/fps": 128,
#     "time/iterations": 282,
#     "time/time_elapsed": 70,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.1265145242214203,
#     "train/entropy_loss": -0.0012651452561840415,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 12.452906608581543,
#     "train/loss": 0.3138505220413208,
#     "train/n_updates": 281,
#     "train/policy_gradient_loss": 0.2565056085586548,
#     "train/ratio_epoch-0": 0.9999999403953552,
#     "train/value_loss": 0.058610040694475174
# }
# {
#     "global_step": 10016,
#     "num_episodes": 46,
#     "rollout/ep_len_mean": 183.9,
#     "rollout/ep_rew_mean": 1377.780029296875,
#     "time/fps": 128,
#     "time/iterations": 313,
#     "time/time_elapsed": 77,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.40760338306427,
#     "train/entropy_loss": -0.014076033607125282,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 115.49972534179688,
#     "train/loss": 14.426054000854492,
#     "train/n_updates": 312,
#     "train/policy_gradient_loss": 4.118495464324951,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 10.321634292602539
# }
# {
#     "global_step": 11008,
#     "num_episodes": 49,
#     "rollout/ep_len_mean": 211.5,
#     "rollout/ep_rew_mean": 1006.3837890625,
#     "time/fps": 129,
#     "time/iterations": 344,
#     "time/time_elapsed": 84,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.4227898120880127,
#     "train/entropy_loss": -0.014227897860109806,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.0104851722717285,
#     "train/loss": -0.1687076985836029,
#     "train/n_updates": 343,
#     "train/policy_gradient_loss": -0.17370963096618652,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.019229831174016
# }
# {
#     "global_step": 12000,
#     "num_episodes": 52,
#     "rollout/ep_len_mean": 278.0,
#     "rollout/ep_rew_mean": 796.8041381835938,
#     "time/fps": 129,
#     "time/iterations": 375,
#     "time/time_elapsed": 92,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.8249613046646118,
#     "train/entropy_loss": -0.01824961230158806,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.06031621992588043,
#     "train/loss": -0.014398825354874134,
#     "train/n_updates": 374,
#     "train/policy_gradient_loss": 0.003733111545443535,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.00011767556861741468
# }
# {
#     "global_step": 13024,
#     "num_episodes": 57,
#     "rollout/ep_len_mean": 280.4,
#     "rollout/ep_rew_mean": 682.7103271484375,
#     "time/fps": 129,
#     "time/iterations": 407,
#     "time/time_elapsed": 100,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.7501571774482727,
#     "train/entropy_loss": -0.0075015714392066,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 15.544510841369629,
#     "train/loss": -0.24105937778949738,
#     "train/n_updates": 406,
#     "train/policy_gradient_loss": -0.40038183331489563,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.16682402789592743
# }
# {
#     "global_step": 14016,
#     "num_episodes": 62,
#     "rollout/ep_len_mean": 181.7,
#     "rollout/ep_rew_mean": 667.2791748046875,
#     "time/fps": 118,
#     "time/iterations": 438,
#     "time/time_elapsed": 117,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.8984914422035217,
#     "train/entropy_loss": -0.008984914049506187,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.846946120262146,
#     "train/loss": -0.03502323478460312,
#     "train/n_updates": 437,
#     "train/policy_gradient_loss": -0.034790705889463425,
#     "train/ratio_epoch-0": 0.9999999403953552,
#     "train/value_loss": 0.008752383291721344
# }
# {
#     "global_step": 15008,
#     "num_episodes": 69,
#     "rollout/ep_len_mean": 162.5,
#     "rollout/ep_rew_mean": 831.5183715820312,
#     "time/fps": 117,
#     "time/iterations": 469,
#     "time/time_elapsed": 127,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.5588834285736084,
#     "train/entropy_loss": -0.005588834173977375,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.88642692565918,
#     "train/loss": -0.16154806315898895,
#     "train/n_updates": 468,
#     "train/policy_gradient_loss": -0.1822795420885086,
#     "train/ratio_epoch-0": 1.0000001192092896,
#     "train/value_loss": 0.026320312172174454
# }
# {
#     "global_step": 16000,
#     "num_episodes": 74,
#     "rollout/ep_len_mean": 165.3,
#     "rollout/ep_rew_mean": 785.9314575195312,
#     "time/fps": 116,
#     "time/iterations": 500,
#     "time/time_elapsed": 137,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6351658701896667,
#     "train/entropy_loss": -0.00635165860876441,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 9.202303886413574,
#     "train/loss": -0.28469717502593994,
#     "train/n_updates": 499,
#     "train/policy_gradient_loss": -0.35651320219039917,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.07816768437623978
# }
# {
#     "global_step": 17024,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 167.8,
#     "rollout/ep_rew_mean": 754.9642333984375,
#     "time/fps": 116,
#     "time/iterations": 532,
#     "time/time_elapsed": 145,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.5680930018424988,
#     "train/entropy_loss": -0.005680929869413376,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.67487907409668,
#     "train/loss": -0.19813674688339233,
#     "train/n_updates": 531,
#     "train/policy_gradient_loss": -0.22023078799247742,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.02777497097849846
# }
# {
#     "global_step": 18016,
#     "num_episodes": 86,
#     "rollout/ep_len_mean": 177.0,
#     "rollout/ep_rew_mean": 933.38232421875,
#     "time/fps": 117,
#     "time/iterations": 563,
#     "time/time_elapsed": 153,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.7816265821456909,
#     "train/entropy_loss": -0.00781626533716917,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.4214891195297241,
#     "train/loss": -0.013269955292344093,
#     "train/n_updates": 562,
#     "train/policy_gradient_loss": -0.010279449634253979,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.0048257592134177685
# }
# {
#     "global_step": 19008,
#     "num_episodes": 92,
#     "rollout/ep_len_mean": 172.8,
#     "rollout/ep_rew_mean": 1021.8934326171875,
#     "time/fps": 116,
#     "time/iterations": 594,
#     "time/time_elapsed": 163,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.025494061410427094,
#     "train/entropy_loss": -0.000254940619925037,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 22.510967254638672,
#     "train/loss": -0.3810257911682129,
#     "train/n_updates": 593,
#     "train/policy_gradient_loss": -0.528056263923645,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.14728540182113647
# }
# {
#     "global_step": 20000,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 166.6,
#     "rollout/ep_rew_mean": 1865.945068359375,
#     "time/fps": 115,
#     "time/iterations": 625,
#     "time/time_elapsed": 172,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.013327173888683319,
#     "train/entropy_loss": -0.00013327173655852675,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 6.883066654205322,
#     "train/loss": -0.1420118510723114,
#     "train/n_updates": 624,
#     "train/policy_gradient_loss": -0.16283245384693146,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.020953882485628128
# }
# Решено!

# %% [markdown]
# # 4 Обобщённая оценка преимущества (general advantage estimation)
# Обобщенная оценка преимущества (GAE) — это метод оценки преимущества, объединяющий ошибку временных различий (TD) и оценку по методу Монте-Карло, что позволяет сбалансировать смещение и дисперсию оценки.
#
# N-шаговая отдача:
# $$G_t ^ {(N)} = \sum_{k = 0} ^ {N - 1} \gamma ^ k r_{t + k} + \gamma ^ N V(s_{t + N}) $$
# $$ G_t ^ {(1)} = r_t + \gamma V(s_{t + 1}) \ \ \ \ \ \ \ \ G_t ^ {(\infty)} = G_t ^ {(T)} = \sum_{k = 0} ^ {T - 1} \gamma ^ k r_{t + k} $$
# $\lambda$-отдача:
# $$G_t (\lambda) = (1-\lambda) \sum_{n = 0} ^ {\infty} \lambda ^ {n - 1} G_t ^ {(n)}, \ \ \ \ \ \ \ 0 \le \lambda \le 1 $$
# Для конечного эпизода $G_t ^ {(n)} = G_t ^ {T - t}$ при $n \ge T - t$:
# $$G_t (\lambda) = (1 - \lambda) \sum_{n =1} ^ {T - t -1} \lambda ^ {n -1} G_t ^n + \lambda ^ {T - t - 1} G_t ^ {T - t}$$
# $$G_t(0) = G_t ^ {(1)} \ \ \ \ \ \ \ \ \ \ \ G_t (1) = G_t ^ {(\infty)} = G_t ^ {(T)} $$
#
# **Обобщённая оценка преимущества (general advantage estimation)**:
# $$ A_t ^ {GAE} = G_t(\lambda) - V(s_t) $$
# Вычисление через TD-ошибку $\delta_t$: $$\delta_t = r_t + \gamma V(s_{t + 1}) - V(s_t)$$
# $$A_t ^ {GAE} = \delta_t + (\gamma \lambda) \delta_{t + 1} + (\gamma \lambda) ^ 2 \delta_{t + 2} + \dots $$
#
# Рекуррентный вариант, удобный для вычисления $A_t ^ {GAE}$ по траектории за один проход:
# $$A_t ^ {GAE} = \delta_t + (\gamma \lambda) A_{t+1} ^ {GAE}$$

# %% [markdown]
# (2 балла)

# %%
class NStepGAEBuffer(NStepAdvantageBuffer):
    def __init__(self, gamma: float = 0.99, gae_lambda: float = 1.0, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.gae_lambda = gae_lambda

    def compute_returns_and_advantage(self, last_value: float, last_terminated: bool) -> None:
        rewards = self.rewards
        episode_starts = self.episode_starts
        values = self.values
        assert len(episode_starts) == len(rewards)
        assert len(values) == len(rewards)

        episode_starts.append(last_terminated)
        values.append(last_value)
        returns = [None] * len(self.rewards)
        advantages = [None] * len(self.rewards)
        # Реализовать вычисление GAE
        last_gae_lam = 0.0
        for step in reversed(range(len(self.rewards))):
            is_next_step_terminal = float(episode_starts[step + 1])
            next_value = values[step + 1]
            
            # Рассчитываем TD-ошибку (delta)
            delta = rewards[step] + self.gamma * next_value * (1.0 - is_next_step_terminal) - values[step]
            
            # Рассчитываем GAE (advantage) с использованием рекуррентной формулы
            last_gae_lam = delta + self.gamma * self.gae_lambda * (1.0 - is_next_step_terminal) * last_gae_lam
            advantages[step] = last_gae_lam
        
        # Рассчитываем returns (G_t = A_t + V(s_t))
        for i in range(len(self.rewards)):
            returns[i] = advantages[i] + values[i]
        self.returns = returns
        self.advantages = advantages

# %%
run_algorithm(
    algorithm_class=PPO,
    algorithm_kwargs=dict(seed=0, normalize_advantage=False, n_epochs=1, clip_range=0.1, policy_class=PolicySeparateFeaturesExtractors,
                         buffer_class=NStepGAEBuffer, buffer_kwargs=dict(gae_lambda=0.95)),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_ppo', monitor_gym=True, name='PPO-GAE', mode='offline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000,
                      save_checkpoint_path='./4_ppo-gae',
                      save_checkpoint_interval=1000)
)
# Out:
# Using cpu device
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_61194/3539175664.py:152: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_61194/3539175664.py:191: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   last_value = self.policy(torch.as_tensor(np.array(new_obs), device=self.device).unsqueeze(0))['value'].item()
# {
#     "global_step": 1024,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 264.0,
#     "rollout/ep_rew_mean": -79.9289321899414,
#     "time/fps": 138,
#     "time/iterations": 32,
#     "time/time_elapsed": 7,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.9764554500579834,
#     "train/entropy_loss": -0.019764553755521774,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.3477659225463867,
#     "train/loss": -0.19749502837657928,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": -0.20203126966953278,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.024300793185830116
# }
# {
#     "global_step": 2016,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 223.55555555555554,
#     "rollout/ep_rew_mean": 288.9956970214844,
#     "time/fps": 149,
#     "time/iterations": 63,
#     "time/time_elapsed": 13,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0968173742294312,
#     "train/entropy_loss": -0.01096817385405302,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.8914268612861633,
#     "train/loss": -0.38243553042411804,
#     "train/n_updates": 62,
#     "train/policy_gradient_loss": -0.542544960975647,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.17107757925987244
# }
# {
#     "global_step": 3008,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 205.9,
#     "rollout/ep_rew_mean": 513.53662109375,
#     "time/fps": 156,
#     "time/iterations": 94,
#     "time/time_elapsed": 19,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.3439520597457886,
#     "train/entropy_loss": -0.013439520262181759,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.453281879425049,
#     "train/loss": 0.24247616529464722,
#     "train/n_updates": 93,
#     "train/policy_gradient_loss": 0.2150207757949829,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.04089491069316864
# }
# {
#     "global_step": 4000,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 211.8,
#     "rollout/ep_rew_mean": 699.7135620117188,
#     "time/fps": 170,
#     "time/iterations": 125,
#     "time/time_elapsed": 23,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.5872857570648193,
#     "train/entropy_loss": -0.015872856602072716,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 2.8899452686309814,
#     "train/loss": -0.12251120805740356,
#     "train/n_updates": 124,
#     "train/policy_gradient_loss": -0.1330132931470871,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.026374932378530502
# }
# {
#     "global_step": 5024,
#     "num_episodes": 22,
#     "rollout/ep_len_mean": 231.7,
#     "rollout/ep_rew_mean": 654.8644409179688,
#     "time/fps": 172,
#     "time/iterations": 157,
#     "time/time_elapsed": 29,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.7231653928756714,
#     "train/entropy_loss": -0.01723165437579155,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.602137565612793,
#     "train/loss": 0.21209895610809326,
#     "train/n_updates": 156,
#     "train/policy_gradient_loss": 0.19735026359558105,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.031980350613594055
# }
# {
#     "global_step": 6016,
#     "num_episodes": 26,
#     "rollout/ep_len_mean": 255.2,
#     "rollout/ep_rew_mean": 688.2764282226562,
#     "time/fps": 165,
#     "time/iterations": 188,
#     "time/time_elapsed": 36,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.5437825918197632,
#     "train/entropy_loss": -0.015437825582921505,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.441490411758423,
#     "train/loss": -0.13394205272197723,
#     "train/n_updates": 187,
#     "train/policy_gradient_loss": -0.14015860855579376,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.021654386073350906
# }
# {
#     "global_step": 7008,
#     "num_episodes": 30,
#     "rollout/ep_len_mean": 230.6,
#     "rollout/ep_rew_mean": 556.8563842773438,
#     "time/fps": 167,
#     "time/iterations": 219,
#     "time/time_elapsed": 41,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0267599821090698,
#     "train/entropy_loss": -0.010267599485814571,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.153804302215576,
#     "train/loss": -0.18052349984645844,
#     "train/n_updates": 218,
#     "train/policy_gradient_loss": -0.19509315490722656,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.024837255477905273
# }
# {
#     "global_step": 8000,
#     "num_episodes": 37,
#     "rollout/ep_len_mean": 177.1,
#     "rollout/ep_rew_mean": 631.7615966796875,
#     "time/fps": 168,
#     "time/iterations": 250,
#     "time/time_elapsed": 47,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0948539972305298,
#     "train/entropy_loss": -0.010948539711534977,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.230175256729126,
#     "train/loss": -0.051947131752967834,
#     "train/n_updates": 249,
#     "train/policy_gradient_loss": -0.0514473132789135,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.010448722168803215
# }
# {
#     "global_step": 9024,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 162.9,
#     "rollout/ep_rew_mean": 639.1373291015625,
#     "time/fps": 169,
#     "time/iterations": 282,
#     "time/time_elapsed": 53,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.1504817008972168,
#     "train/entropy_loss": -0.011504816822707653,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 11.624857902526855,
#     "train/loss": 0.3220202922821045,
#     "train/n_updates": 281,
#     "train/policy_gradient_loss": 0.27744415402412415,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.056080956012010574
# }
# {
#     "global_step": 10016,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 202.3,
#     "rollout/ep_rew_mean": 738.2047729492188,
#     "time/fps": 170,
#     "time/iterations": 313,
#     "time/time_elapsed": 58,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.7448678016662598,
#     "train/entropy_loss": -0.017448676750063896,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.6963658332824707,
#     "train/loss": 0.37671351432800293,
#     "train/n_updates": 312,
#     "train/policy_gradient_loss": 0.2121657133102417,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.18199647963047028
# }
# {
#     "global_step": 11008,
#     "num_episodes": 50,
#     "rollout/ep_len_mean": 235.1,
#     "rollout/ep_rew_mean": 654.4415893554688,
#     "time/fps": 173,
#     "time/iterations": 344,
#     "time/time_elapsed": 63,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.7644404172897339,
#     "train/entropy_loss": -0.017644403502345085,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.7645634412765503,
#     "train/loss": -0.1538919359445572,
#     "train/n_updates": 343,
#     "train/policy_gradient_loss": -0.15015794336795807,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.013910412788391113
# }
# {
#     "global_step": 12000,
#     "num_episodes": 56,
#     "rollout/ep_len_mean": 230.9,
#     "rollout/ep_rew_mean": 486.57098388671875,
#     "time/fps": 172,
#     "time/iterations": 375,
#     "time/time_elapsed": 69,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0939902067184448,
#     "train/entropy_loss": -0.010939901694655418,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 16.93526840209961,
#     "train/loss": 2.234410524368286,
#     "train/n_updates": 374,
#     "train/policy_gradient_loss": 0.552340030670166,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 1.6930104494094849
# }
# {
#     "global_step": 13024,
#     "num_episodes": 62,
#     "rollout/ep_len_mean": 161.7,
#     "rollout/ep_rew_mean": 722.525634765625,
#     "time/fps": 177,
#     "time/iterations": 407,
#     "time/time_elapsed": 73,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.8507400751113892,
#     "train/entropy_loss": -0.008507400751113892,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 10.607766151428223,
#     "train/loss": -0.22978895902633667,
#     "train/n_updates": 406,
#     "train/policy_gradient_loss": -0.2766713500022888,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.05538979917764664
# }
# {
#     "global_step": 14016,
#     "num_episodes": 68,
#     "rollout/ep_len_mean": 166.5,
#     "rollout/ep_rew_mean": 770.3206176757812,
#     "time/fps": 176,
#     "time/iterations": 438,
#     "time/time_elapsed": 79,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.978606641292572,
#     "train/entropy_loss": -0.009786066599190235,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.24514102935791,
#     "train/loss": 0.11969674378633499,
#     "train/n_updates": 437,
#     "train/policy_gradient_loss": 0.11904684454202652,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.010435969568789005
# }
# {
#     "global_step": 15008,
#     "num_episodes": 74,
#     "rollout/ep_len_mean": 173.4,
#     "rollout/ep_rew_mean": 831.763671875,
#     "time/fps": 173,
#     "time/iterations": 469,
#     "time/time_elapsed": 86,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.8257417678833008,
#     "train/entropy_loss": -0.008257417939603329,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.7579602003097534,
#     "train/loss": -0.02614108845591545,
#     "train/n_updates": 468,
#     "train/policy_gradient_loss": -0.022436756640672684,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.004553087987005711
# }
# {
#     "global_step": 16000,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 182.2,
#     "rollout/ep_rew_mean": 980.0574951171875,
#     "time/fps": 172,
#     "time/iterations": 500,
#     "time/time_elapsed": 92,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.3190068006515503,
#     "train/entropy_loss": -0.013190067373216152,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.150613307952881,
#     "train/loss": 0.15055179595947266,
#     "train/n_updates": 499,
#     "train/policy_gradient_loss": 0.1486903876066208,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.015051472932100296
# }
# {
#     "global_step": 17024,
#     "num_episodes": 85,
#     "rollout/ep_len_mean": 170.5,
#     "rollout/ep_rew_mean": 582.930908203125,
#     "time/fps": 173,
#     "time/iterations": 532,
#     "time/time_elapsed": 98,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.9661896824836731,
#     "train/entropy_loss": -0.009661896154284477,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.368040561676025,
#     "train/loss": -0.17735660076141357,
#     "train/n_updates": 531,
#     "train/policy_gradient_loss": -0.18768370151519775,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.01998899318277836
# }
# {
#     "global_step": 18016,
#     "num_episodes": 92,
#     "rollout/ep_len_mean": 157.9,
#     "rollout/ep_rew_mean": 661.0223388671875,
#     "time/fps": 174,
#     "time/iterations": 563,
#     "time/time_elapsed": 103,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.679375410079956,
#     "train/entropy_loss": -0.0067937541753053665,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.087644100189209,
#     "train/loss": -0.11147262156009674,
#     "train/n_updates": 562,
#     "train/policy_gradient_loss": -0.11776264756917953,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.013083778321743011
# }
# {
#     "global_step": 19008,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 156.9,
#     "rollout/ep_rew_mean": 742.26611328125,
#     "time/fps": 174,
#     "time/iterations": 594,
#     "time/time_elapsed": 109,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.9327639937400818,
#     "train/entropy_loss": -0.009327639825642109,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.8007946014404297,
#     "train/loss": -0.059319619089365005,
#     "train/n_updates": 593,
#     "train/policy_gradient_loss": -0.05483844503760338,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.004846463445574045
# }
# {
#     "global_step": 20000,
#     "num_episodes": 104,
#     "rollout/ep_len_mean": 155.7,
#     "rollout/ep_rew_mean": 670.3373413085938,
#     "time/fps": 172,
#     "time/iterations": 625,
#     "time/time_elapsed": 115,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0863429307937622,
#     "train/entropy_loss": -0.010863428935408592,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.910449028015137,
#     "train/loss": 0.2598673105239868,
#     "train/n_updates": 624,
#     "train/policy_gradient_loss": 0.23475021123886108,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.03598051518201828
# }
# {
#     "global_step": 21024,
#     "num_episodes": 112,
#     "rollout/ep_len_mean": 147.2,
#     "rollout/ep_rew_mean": 606.746337890625,
#     "time/fps": 172,
#     "time/iterations": 657,
#     "time/time_elapsed": 121,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.7037811279296875,
#     "train/entropy_loss": -0.007037810981273651,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.866084098815918,
#     "train/loss": -0.12929469347000122,
#     "train/n_updates": 656,
#     "train/policy_gradient_loss": -0.1330854743719101,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.010828591883182526
# }
# {
#     "global_step": 22016,
#     "num_episodes": 118,
#     "rollout/ep_len_mean": 146.5,
#     "rollout/ep_rew_mean": 687.6227416992188,
#     "time/fps": 172,
#     "time/iterations": 688,
#     "time/time_elapsed": 127,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6939432621002197,
#     "train/entropy_loss": -0.006939432583749294,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.764571666717529,
#     "train/loss": -0.16638615727424622,
#     "train/n_updates": 687,
#     "train/policy_gradient_loss": -0.18512451648712158,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.02567778155207634
# }
# {
#     "global_step": 23008,
#     "num_episodes": 124,
#     "rollout/ep_len_mean": 160.7,
#     "rollout/ep_rew_mean": 722.9890747070312,
#     "time/fps": 170,
#     "time/iterations": 719,
#     "time/time_elapsed": 135,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.3177189826965332,
#     "train/entropy_loss": -0.013177189975976944,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.23564338684082,
#     "train/loss": -0.19999559223651886,
#     "train/n_updates": 718,
#     "train/policy_gradient_loss": -0.21356916427612305,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.02675076387822628
# }
# {
#     "global_step": 24000,
#     "num_episodes": 130,
#     "rollout/ep_len_mean": 158.5,
#     "rollout/ep_rew_mean": 642.4398803710938,
#     "time/fps": 166,
#     "time/iterations": 750,
#     "time/time_elapsed": 144,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.148014783859253,
#     "train/entropy_loss": -0.011480147950351238,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 5.637432098388672,
#     "train/loss": 0.18256817758083344,
#     "train/n_updates": 749,
#     "train/policy_gradient_loss": 0.16962161660194397,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.024426709860563278
# }
# {
#     "global_step": 25024,
#     "num_episodes": 135,
#     "rollout/ep_len_mean": 182.2,
#     "rollout/ep_rew_mean": 690.7877197265625,
#     "time/fps": 163,
#     "time/iterations": 782,
#     "time/time_elapsed": 152,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.27249014377594,
#     "train/entropy_loss": -0.012724901549518108,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.5630443096160889,
#     "train/loss": 0.05751575529575348,
#     "train/n_updates": 781,
#     "train/policy_gradient_loss": 0.06231016665697098,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.007930492982268333
# }
# {
#     "global_step": 26016,
#     "num_episodes": 142,
#     "rollout/ep_len_mean": 168.6,
#     "rollout/ep_rew_mean": 618.05615234375,
#     "time/fps": 162,
#     "time/iterations": 813,
#     "time/time_elapsed": 160,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.962415337562561,
#     "train/entropy_loss": -0.00962415337562561,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 95.20072174072266,
#     "train/loss": 8.253530502319336,
#     "train/n_updates": 812,
#     "train/policy_gradient_loss": 2.763737440109253,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 5.499417304992676
# }
# {
#     "global_step": 27008,
#     "num_episodes": 148,
#     "rollout/ep_len_mean": 165.5,
#     "rollout/ep_rew_mean": 828.3758544921875,
#     "time/fps": 161,
#     "time/iterations": 844,
#     "time/time_elapsed": 167,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6748552322387695,
#     "train/entropy_loss": -0.006748551968485117,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.556947231292725,
#     "train/loss": 0.13015571236610413,
#     "train/n_updates": 843,
#     "train/policy_gradient_loss": 0.12636025249958038,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.010544013231992722
# }
# {
#     "global_step": 28000,
#     "num_episodes": 153,
#     "rollout/ep_len_mean": 171.5,
#     "rollout/ep_rew_mean": 1021.1487426757812,
#     "time/fps": 159,
#     "time/iterations": 875,
#     "time/time_elapsed": 175,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.4087690114974976,
#     "train/entropy_loss": -0.01408769004046917,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.501672625541687,
#     "train/loss": -0.026770472526550293,
#     "train/n_updates": 874,
#     "train/policy_gradient_loss": -0.013851329684257507,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.0011685462668538094
# }
# {
#     "global_step": 29024,
#     "num_episodes": 157,
#     "rollout/ep_len_mean": 192.6,
#     "rollout/ep_rew_mean": 951.5158081054688,
#     "time/fps": 158,
#     "time/iterations": 907,
#     "time/time_elapsed": 183,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.1671674251556396,
#     "train/entropy_loss": -0.011671674437820911,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 0.7945981621742249,
#     "train/loss": -0.03454015031456947,
#     "train/n_updates": 906,
#     "train/policy_gradient_loss": -0.03440691903233528,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.01153844129294157
# }
# {
#     "global_step": 30016,
#     "num_episodes": 163,
#     "rollout/ep_len_mean": 202.6,
#     "rollout/ep_rew_mean": 868.4406127929688,
#     "time/fps": 158,
#     "time/iterations": 938,
#     "time/time_elapsed": 189,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.1302733421325684,
#     "train/entropy_loss": -0.011302732862532139,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.6814868450164795,
#     "train/loss": 0.046919792890548706,
#     "train/n_updates": 937,
#     "train/policy_gradient_loss": 0.05343344807624817,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.004789074882864952
# }
# {
#     "global_step": 31008,
#     "num_episodes": 170,
#     "rollout/ep_len_mean": 141.1,
#     "rollout/ep_rew_mean": 597.0591430664062,
#     "time/fps": 159,
#     "time/iterations": 969,
#     "time/time_elapsed": 194,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.24142397940158844,
#     "train/entropy_loss": -0.00241423980332911,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.3346643447875977,
#     "train/loss": -0.08019346743822098,
#     "train/n_updates": 968,
#     "train/policy_gradient_loss": -0.0903053805232048,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.012526152655482292
# }
# {
#     "global_step": 32000,
#     "num_episodes": 177,
#     "rollout/ep_len_mean": 139.1,
#     "rollout/ep_rew_mean": 787.4566650390625,
#     "time/fps": 159,
#     "time/iterations": 1000,
#     "time/time_elapsed": 200,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.36678141355514526,
#     "train/entropy_loss": -0.0036678139586001635,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 8.047114372253418,
#     "train/loss": -0.20266610383987427,
#     "train/n_updates": 999,
#     "train/policy_gradient_loss": -0.23161180317401886,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.03261351212859154
# }
# {
#     "global_step": 33024,
#     "num_episodes": 183,
#     "rollout/ep_len_mean": 156.4,
#     "rollout/ep_rew_mean": 1222.432373046875,
#     "time/fps": 159,
#     "time/iterations": 1032,
#     "time/time_elapsed": 206,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.29879921674728394,
#     "train/entropy_loss": -0.0029879920184612274,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 6.4462690353393555,
#     "train/loss": -0.14991512894630432,
#     "train/n_updates": 1031,
#     "train/policy_gradient_loss": -0.16898438334465027,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.02205725386738777
# }
# {
#     "global_step": 34016,
#     "num_episodes": 189,
#     "rollout/ep_len_mean": 171.2,
#     "rollout/ep_rew_mean": 1300.5343017578125,
#     "time/fps": 158,
#     "time/iterations": 1063,
#     "time/time_elapsed": 214,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.1431248188018799,
#     "train/entropy_loss": -0.011431247927248478,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 3.9439175128936768,
#     "train/loss": 0.11448383331298828,
#     "train/n_updates": 1062,
#     "train/policy_gradient_loss": 0.10833873599767685,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.017576340585947037
# }
# {
#     "global_step": 35008,
#     "num_episodes": 195,
#     "rollout/ep_len_mean": 181.5,
#     "rollout/ep_rew_mean": 898.8966064453125,
#     "time/fps": 157,
#     "time/iterations": 1094,
#     "time/time_elapsed": 222,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.19754159450531,
#     "train/entropy_loss": -0.011975415982306004,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 2.6234772205352783,
#     "train/loss": 0.08715260028839111,
#     "train/n_updates": 1093,
#     "train/policy_gradient_loss": 0.09175990521907806,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.0073681119829416275
# }
# {
#     "global_step": 36000,
#     "num_episodes": 200,
#     "rollout/ep_len_mean": 177.8,
#     "rollout/ep_rew_mean": 646.1810302734375,
#     "time/fps": 155,
#     "time/iterations": 1125,
#     "time/time_elapsed": 232,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.6371692419052124,
#     "train/entropy_loss": -0.006371692288666964,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 6.10287618637085,
#     "train/loss": -0.17329414188861847,
#     "train/n_updates": 1124,
#     "train/policy_gradient_loss": -0.19792619347572327,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.031003743410110474
# }
# {
#     "global_step": 37024,
#     "num_episodes": 206,
#     "rollout/ep_len_mean": 182.4,
#     "rollout/ep_rew_mean": 979.2841796875,
#     "time/fps": 153,
#     "time/iterations": 1157,
#     "time/time_elapsed": 240,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.497556209564209,
#     "train/entropy_loss": -0.014975561760365963,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.85238516330719,
#     "train/loss": 0.07975785434246063,
#     "train/n_updates": 1156,
#     "train/policy_gradient_loss": 0.08801400661468506,
#     "train/ratio_epoch-0": 0.9999999403953552,
#     "train/value_loss": 0.0067194136790931225
# }
# {
#     "global_step": 38016,
#     "num_episodes": 210,
#     "rollout/ep_len_mean": 205.0,
#     "rollout/ep_rew_mean": 1037.20703125,
#     "time/fps": 152,
#     "time/iterations": 1188,
#     "time/time_elapsed": 248,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.0581151247024536,
#     "train/entropy_loss": -0.010581150650978088,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 4.854226112365723,
#     "train/loss": -0.17295046150684357,
#     "train/n_updates": 1187,
#     "train/policy_gradient_loss": -0.18043416738510132,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.01806486025452614
# }
# {
#     "global_step": 39008,
#     "num_episodes": 216,
#     "rollout/ep_len_mean": 197.5,
#     "rollout/ep_rew_mean": 692.9749755859375,
#     "time/fps": 152,
#     "time/iterations": 1219,
#     "time/time_elapsed": 255,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 1.2605311870574951,
#     "train/entropy_loss": -0.01260531134903431,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 1.9222261905670166,
#     "train/loss": -0.09113438427448273,
#     "train/n_updates": 1218,
#     "train/policy_gradient_loss": -0.08501153439283371,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.006482458673417568
# }
# {
#     "global_step": 40000,
#     "num_episodes": 222,
#     "rollout/ep_len_mean": 165.8,
#     "rollout/ep_rew_mean": 701.8998413085938,
#     "time/fps": 152,
#     "time/iterations": 1250,
#     "time/time_elapsed": 262,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.04617065563797951,
#     "train/entropy_loss": -0.00046170654240995646,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 7.880483627319336,
#     "train/loss": -0.1916457712650299,
#     "train/n_updates": 1249,
#     "train/policy_gradient_loss": -0.21740922331809998,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.026225166395306587
# }
# {
#     "global_step": 41024,
#     "num_episodes": 228,
#     "rollout/ep_len_mean": 166.3,
#     "rollout/ep_rew_mean": 1721.397216796875,
#     "time/fps": 151,
#     "time/iterations": 1282,
#     "time/time_elapsed": 270,
#     "train/clip_fraction": 0.0,
#     "train/clip_range": 0.1,
#     "train/entropy": 0.02521100640296936,
#     "train/entropy_loss": -0.0002521100686863065,
#     "train/fraction-0.05_epoch-0": 0.0,
#     "train/fraction-0.1_epoch-0": 0.0,
#     "train/fraction-0.2_epoch-0": 0.0,
#     "train/grad_norm": 2.644582509994507,
#     "train/loss": 0.06390554457902908,
#     "train/n_updates": 1281,
#     "train/policy_gradient_loss": 0.05799597129225731,
#     "train/ratio_epoch-0": 1.0,
#     "train/value_loss": 0.006161682307720184
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>█▆▅▅▆█▆▃▂▅▆▆▂▃▃▃▃▂▂▂▁▁▂▂▃▃▂▃▄▅▁▁▂▃▃▃▃▅▄▃</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▂▃▄▄▄▃▄▄▄▄▃▄▄▅▅▄▄▄▄▄▄▄▄▄▄▅▅▅▅▄▄▆▆▅▄▅▅▄█</td></tr><tr><td>time/fps</td><td>▁▃▄▇▇▆▆▆▇▇▇▇██▇▇▇▇▇▇▇▇▇▆▅▅▅▅▅▅▅▅▅▅▄▄▄▄▄▃</td></tr><tr><td>time/iterations</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy</td><td>█▅▆▇▇▆▅▅▅▇▇▅▄▄▄▆▄▃▄▅▃▃▆▅▅▄▃▆▅▅▂▂▂▅▅▃▆▅▅▁</td></tr><tr><td>train/entropy_loss</td><td>▁▄▃▂▂▃▄▄▄▂▂▄▅▅▅▃▅▆▅▄▆▆▃▄▄▅▆▃▄▄▇▇▇▄▄▆▃▄▄█</td></tr><tr><td>train/fraction-0.05_epoch-0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/fraction-0.1_epoch-0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/fraction-0.2_epoch-0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▂▁▁▂▂▁▁▁▁▁▁▂▁▂▁▁▁█▁▁▁▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▁▁▂▁▁▁▁▁▂▂▁▃▁▁▁▁▁▁▁▂▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/n_updates</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▁▃▂▃▂▂▂▃▃▂▃▂▂▂▂▂▂▂▃▂▂▂▃▂█▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>train/ratio_epoch-0</td><td>████████████████████████████████████▁███</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>41024</td></tr><tr><td>num_episodes</td><td>228</td></tr><tr><td>rollout/ep_len_mean</td><td>166.3</td></tr><tr><td>rollout/ep_rew_mean</td><td>1721.39722</td></tr><tr><td>time/fps</td><td>151</td></tr><tr><td>time/iterations</td><td>1282</td></tr><tr><td>time/time_elapsed</td><td>270</td></tr><tr><td>train/clip_fraction</td><td>0</td></tr><tr><td>train/clip_range</td><td>0.1</td></tr><tr><td>train/entropy</td><td>0.02521</td></tr><tr><td>train/entropy_loss</td><td>-0.00025</td></tr><tr><td>train/fraction-0.05_epoch-0</td><td>0</td></tr><tr><td>train/fraction-0.1_epoch-0</td><td>0</td></tr><tr><td>train/fraction-0.2_epoch-0</td><td>0</td></tr><tr><td>train/grad_norm</td><td>2.64458</td></tr><tr><td>train/loss</td><td>0.06391</td></tr><tr><td>train/n_updates</td><td>1281</td></tr><tr><td>train/policy_gradient_loss</td><td>0.058</td></tr><tr><td>train/ratio_epoch-0</td><td>1</td></tr><tr><td>train/value_loss</td><td>0.00616</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/hse/RL/practices/prac7/wandb/offline-run-20251114_225430-wf0140ds<code>
# Find logs at: <code>./wandb/offline-run-20251114_225430-wf0140ds/logs</code>

# %% [markdown]
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)
