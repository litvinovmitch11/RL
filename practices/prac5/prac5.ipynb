# %%
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    COLAB = True
except:
    COLAB = False

# !pip install gymnasium==0.29.1 vizdoom==1.2.4 wandb==0.19.1
# Out:
# Requirement already satisfied: gymnasium==0.29.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (0.29.1)
# Requirement already satisfied: vizdoom==1.2.4 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (1.2.4)
# Requirement already satisfied: wandb==0.19.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (0.19.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gymnasium==0.29.1) (2.2.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gymnasium==0.29.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gymnasium==0.29.1) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gymnasium==0.29.1) (0.0.4)
# Requirement already satisfied: pygame>=2.1.3 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from vizdoom==1.2.4) (2.6.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (8.3.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (3.1.45)
# Requirement already satisfied: platformdirs in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (4.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (5.29.5)
# Requirement already satisfied: psutil>=5.0.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (7.1.0)
# Requirement already satisfied: pydantic<3,>=2.6 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (2.12.3)
# Requirement already satisfied: pyyaml in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (2.32.5)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (2.42.1)
# Requirement already satisfied: setproctitle in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (1.3.7)
# Requirement already satisfied: setuptools in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from wandb==0.19.1) (80.9.0)
# Requirement already satisfied: six>=1.4.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb==0.19.1) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb==0.19.1) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from pydantic<3,>=2.6->wandb==0.19.1) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.19.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.19.1) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mitchell/dev/RL/venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.19.1) (5.0.2)

# %%
import json
import math
import random
import sys
import os
import time
from collections import deque
from typing import Dict, Type, Any, Tuple, NamedTuple, Optional, Union, Generator, List

import gymnasium as gym
import gymnasium.spaces as spaces
from gymnasium.vector import AsyncVectorEnv, SyncVectorEnv
from gymnasium.wrappers import ResizeObservation, GrayScaleObservation, RecordEpisodeStatistics, TransformReward, \
    FrameStack
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch import nn
from torch.distributions import Categorical
import vizdoom
from vizdoom import gymnasium_wrapper

try:
    import wandb
    WANDB_IS_AVAILABLE = True
except ImportError:
    WANDB_IS_AVAILABLE = False

os.environ["WANDB_API_KEY"] = "TODO"

# %% [markdown]
# # Градиент стратегии: REINFORCE
#
# Обозначения:
# - $s$ - состояние, $r$ - вознаграждение, $a$ - действие
# - Условное распределение действий $\pi(a | s)$ - стратегия агента
# - $\tau$ - траектория: $(s_0, r_0, a_0), \dots, (s_T, r_T, a_T)$
# - Отдача $G(\tau) = \sum_{t = 0} ^ T r_t \gamma ^ t$
# - $G_t = r_t + r_{t + 1} \gamma + \dots + r_{T} \gamma ^ {T - t}$
# - Функция полезности состояний: $V(s_{t}) = \mathbb{E}[G_t]$
# - Функция полезности действий: $Q(s_t, a_t) = \mathbb{E}[r_t + \gamma V(s_{t + 1}) | a_t]$
#
# В некоторых задачах для нахождения удовлетворительной стратегии необязательно в точности знать структуру всей среды. Например, в задаче поднятия кубика робототехнической рукой вместо точной аппроксимации полезности $Q(s,a)$ достаточно знать, что выгоднее: двигаться вправо, если кубик справа, и влево в ином случае. С этим же наблюдением связано и предположение, что задача поиска удовлетворительной стратегии проще, нежели задача точной оценки функции полезности.
#
# В данном семинаре познакомимся с простейшим методом прямой оптимизации стратегии REINFORCE, в котором параметры, задающие вероятностную стратегию, изменяются в соответствии с градиентом математического ожидания отдач:
#
# $$J(\theta)= \mathbb{E}[G(\tau)],$$
#
# $$\theta \leftarrow \theta +\alpha \nabla_{\theta} J(\theta),$$
#
# В первом выражении математическое ожидание берется по распределениям начальных состояний, вероятностным функциям переходов и вознаграждений среды, а также по вероятностной стратегии агента $\pi_\theta$. Благодаря теореме о существовании стационарного распределения марковской цепи, это выражение может быть переписано через стационарное распределение $d^\pi$ посещения состояний в среде:
#
# $$J(\theta)= \mathbb{E}_{s \sim d^\pi}[V^{\pi}(s)] = \mathbb{E}_{s \sim d^\pi, a \sim \pi(s)} [Q^{\pi}(s, a)] =: \mathbb{E}_\pi [Q^{\pi}(s, a)].$$
#
# Метод REINFORCE также использует теорему о градиенте стратегии, на основе которой построено целое семейство алгоритмов прямой оптимизации стратегии и актор-критиков. Теорема о градиенте стратегии связывает градиент целевой функции $J$ и градиент самой стратегии:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [Q^\pi(s, a) \nabla_\theta \ln \pi_\theta(a \vert s)]$$
#
# Для оценки полезности действий $Q^\pi(s, a)$ REINFORCE использует несмещенную Монте-Карло оценку на основе полученных в среде отдач $G_t$ (за некоторое фиксированное число эпизодов в среде). С учетом этого обновление весов осуществляется по правилу:
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [G_t \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# Более подробное (но все равно короткое) описание градиента стратегии, и в частности REINFORCE, можно посмотреть в [блоге Lilian Weng из OpenAI](https://lilianweng.github.io/posts/2018-04-08-policy-gradient/#policy-gradient), либо полноценно разобраться в соответствующей секции классического учебника Саттона и Барто.

# %% [markdown]
# ### Environment: Vizdoom
# Среда для экспериментов: **Vizdoom**. Задача: **VizdoomCorridor-v0**.
#
# Карта представляет собой коридор со стреляющими противниками по обеим сторонам. Зелёная броня размещена на противоположном конце коридора. Цель агента — добраться до предмета. Награда пропорциональна (отрицательна или положительна) изменению расстояния между игроком и жилетом.
# - Вознаграждение: +dX за приближение к броне, -dX за отдаление от брони, -100 за смерть.
# - Агенту доступны 7 действий: движение вперед/назад/влево/вправо, поворот влево/вправо, стрельба.
# - Ограничение по времени: 2100 шагов
#
# Для ускорения обучения агента рассматриваем самый простой уровень сложности `doom_skill = 1`.

# %%
def create_vizdoom_config(verbose=False):
    # Создаёт файл сценария VizdoomCorridor с уровнем сложности doom_skill = 1

    deadly_corridor_doom_skill_1 = """
    # Lines starting with # are treated as comments (or with whitespaces+#).
    # It doesn't matter if you use capital letters or not.
    # It doesn't matter if you use underscore or camel notation for keys, e.g. episode_timeout is the same as episodeTimeout.
    """
    deadly_corridor_doom_skill_1 += f"\ndoom_scenario_path = {os.path.relpath(os.path.dirname(vizdoom.__file__))}/scenarios/deadly_corridor.wad\n"
    deadly_corridor_doom_skill_1 += """
    # Skill 5 is recommended for the scenario to be a challenge.
    doom_skill = 1

    # Rewards
    death_penalty = 100
    #living_reward = 0

    # Rendering options
    screen_resolution = RES_320X240
    screen_format = CRCGCB
    render_hud = true
    render_crosshair = false
    render_weapon = true
    render_decals = false
    render_particles = false
    window_visible = true

    episode_timeout = 2100

    # Available buttons
    available_buttons =
      {
        MOVE_LEFT
        MOVE_RIGHT
        ATTACK
        MOVE_FORWARD
        MOVE_BACKWARD
        TURN_LEFT
        TURN_RIGHT
      }

    # Game variables that will be in the state
    available_game_variables = { HEALTH }

    mode = PLAYER
    """

    config_file_name = f'deadly_corridor_doom-skill-1.cfg'
    with open(config_file_name, 'w') as file_obj:
        print(deadly_corridor_doom_skill_1, file=file_obj)

    if verbose:
        print(deadly_corridor_doom_skill_1)

    return os.path.realpath(config_file_name)


def source_env_info():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    obs, _ = env.reset()
    plt.imshow(obs['screen'])
    plt.show()
    print(env.env.env.spec.kwargs)

source_env_info()
# Out:
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# {'scenario_file': '/home/mitchell/dev/RL/practices/prac5/deadly_corridor_doom-skill-1.cfg'}

# %% [markdown]
# ### Wrappers

# %%
class ImageExtractorWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = env.observation_space['screen']

    def observation(self, observation: Dict) -> np.ndarray:
        return observation['screen']


def make_env():
    config_file_path = create_vizdoom_config()
    env = gym.make('VizdoomCorridor-v0', **{'scenario_file': config_file_path})
    env = ImageExtractorWrapper(env)
    env = GrayScaleObservation(env)
    env = ResizeObservation(env, shape=84)
    env = FrameStack(env, num_stack=3)
    env = RecordEpisodeStatistics(env)
    env = TransformReward(env, f=lambda reward: reward / 100.)

    return env


def wrapped_env_info():
    config_file_path = create_vizdoom_config()
    env = make_env()
    env.reset()
    terminated = False
    while not terminated:
        obs, reward, terminated, truncated, info = env.step(env.action_space.sample())

    fig, axes = plt.subplots(1, 3, figsize=(12, 3))
    for ax, frame in zip(axes, obs):
        ax.imshow(frame, cmap='gray')

    print('Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape:', obs.shape)
    plt.show()
    print('info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах\n', info)

DEMO_WRAPPED_ENV = True
if DEMO_WRAPPED_ENV:
    wrapped_env_info()
# Out:
# Наблюдение - стек из 3х последовательных изображений 84х84 в оттенках серого, shape: (3, 84, 84)
# info на последнем шаге содержит статистику эпизода: r - суммарное вознаграждение, l - длина эпизода, t - продолжительность эпизода в секундах
#  {'episode': {'r': array([-93.77255], dtype=float32), 'l': array([272], dtype=int32), 't': array([0.37941], dtype=float32)}}

# %% [markdown]
# ### Misc

# %%
def set_seed_everywhere(seed: int, using_cuda: bool = False) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

    if using_cuda:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 1 REINFORCE

# %% [markdown]
# ### Policy
# Основные компоненты ReinforcePolicy:
# - `features_extractor` - свёрточный энкодер, кодирующий изображения в латентный вектор
# - `action_net` - полносвязный слой, который выдаёт логиты действий для предсказания вероятностей

# %% [markdown]
# ![policy](data:image/png;base64,...)

# %%
class Encoder(nn.Module):
    def __init__(
            self,
            observation_space: gym.Space,
            features_dim: int = 512,
    ) -> None:
        super().__init__()
        self.features_dim = features_dim
        n_input_channels = observation_space.shape[0]
        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=8, stride=4, padding=0),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=0),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=0),
            nn.ReLU(),
            nn.Flatten(),
        )

        with torch.no_grad():
            n_flatten = self.cnn(torch.as_tensor(observation_space.sample()[None]).float()).shape[1]

        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))


class ReinforcePolicy(nn.Module):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5},):
        super().__init__()
        self.observation_space = observation_space
        self.action_space = action_space
        self.lr = lr
        self.optimizer_class = optimizer_class
        self.optimizer_kwargs = dict(optimizer_kwargs)
        self.features_extractor = self.make_features_extractor()
        self.action_net = nn.Linear(self.features_extractor.features_dim, self.action_space.n)
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)

    def make_features_extractor(self):
        return Encoder(self.observation_space)

    def extract_features(self, obs: torch.Tensor) -> torch.Tensor:
        obs = obs.float() / 255.
        features = self.features_extractor(obs)

        return features

    def forward(self, obs: torch.Tensor, deterministic: bool = False) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)

        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        actions = distribution.mode() if deterministic else distribution.sample()
        actions = actions.reshape((-1, *self.action_space.shape))

        return {'features': features, 'action': actions}

    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        features = self.extract_features(obs)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()

        return {'features': features, 'log_prob': log_prob, 'entropy': entropy}

    def set_training_mode(self, mode: bool) -> None:
        self.train(mode)

# %% [markdown]
# ### Buffer
# В буфере хранятся траектории, собранные агентом. Также в буфере производится вычисление частичных отдач по траекториям.

# %%
class BufferSamples(NamedTuple):
    observations: torch.Tensor
    actions: torch.Tensor
    returns: torch.Tensor


class Buffer:
    def __init__(
            self,
            gamma: float = 0.99,
            device: Union[torch.device, str] = "cpu",
    ):
        self.device = torch.device(device)
        self.gamma = gamma
        self.observations = None
        self.actions = None
        self.rewards = None
        self.returns = None

    def reset(self) -> None:
        self.observations = []
        self.actions = []
        self.rewards = []
        self.returns = None

    def size(self) -> int:
        return len(self.actions)

    def add(
            self,
            obs: np.ndarray,
            action: int,
            reward: float,
    ) -> None:
        self.observations.append(obs)
        self.actions.append(action)
        self.rewards.append(reward)

    def to_torch(self, array: np.ndarray) -> torch.Tensor:
        return torch.tensor(array, device=self.device)

    def _get_samples(
            self,
            batch_inds: np.ndarray,
    ) -> BufferSamples:
        observations = self.to_torch(self.observations[batch_inds])
        actions = self.to_torch(self.actions[batch_inds])
        returns = self.to_torch(self.returns[batch_inds])

        return BufferSamples(observations=observations, actions=actions, returns=returns)

    def get(self) -> BufferSamples:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        self.observations = np.asarray(self.observations)
        self.actions = np.asarray(self.actions)
        self.returns = np.asarray(self.returns, dtype=np.float32)

        return self._get_samples(indices)

    def compute_returns(self) -> None:
        returns = [None] * len(self.rewards)
        reward_to_go = 0
        for step in reversed(range(len(self.rewards))):
            reward_to_go = self.rewards[step] + self.gamma * reward_to_go
            returns[step] = reward_to_go

        self.returns = returns

# %% [markdown]
# ### Обучение стратегии по методу REINFORCE
# - Метод `learn`: реализует основной цикл RL-обучения: чередование фазы сбора данных (траекторий) агентом в среде - `collect_rollouts` и фазы обучения агента - `train`.
# - Метод `collect_rollouts`: агент выполняет действия в среде согласно текущей стратегии, собирая триплеты **<observation, action, reward>** в буфер
# - Метод `train`: обучение на собранных данных. Функция потерь состоит из двух слагаемых: градиент стратегии и энтропийная регуляризация. Энтропийная регуляризация делает стратегию более стохастичной, т.е. более устойчивой к шуму, помогает исследовать среду, предотвращает сходимость к субоптимальному решению (особенно в средах с дискретными действиями)

# %% [markdown]
# ![learn](data:image/png;base64,...)

# %% [markdown]
# ![reinforce](data:image/png;base64,...)

# %%
class Reinforce:
    def __init__(
            self,
            env: gym.Env,
            learning_rate: float = 2.5e-4,
            gamma: float = 0.99,
            ent_coef: float = 0.001,
            max_grad_norm: float = 0.5,
            stats_window_size: int = 10,
            policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
            policy_kwargs: Optional[Dict[str, Any]] = None,
            buffer_class: Type[Buffer] = Buffer,
            buffer_kwargs: Optional[Dict[str, Any]] = None,
            seed: Optional[int] = None,
            device: Union[torch.device, str] = "cuda",
    ):
        self.device = device if isinstance(device, torch.device) else torch.device(device)
        print(f"Using {self.device} device")

        self.policy_kwargs = {} if policy_kwargs is None else policy_kwargs

        self.num_timesteps = 0
        self._num_timesteps_at_start = 0
        self._episode_num = 0
        self.seed = seed
        self.start_time = 0.0
        self.learning_rate = learning_rate
        self._last_obs = None
        self._stats_window_size = stats_window_size
        self.ep_info_buffer = deque(maxlen=self._stats_window_size)
        self._n_updates = 0

        self.observation_space = env.observation_space
        self.action_space = env.action_space
        self.env = env

        self.n_steps = None
        self.gamma = gamma
        self.ent_coef = ent_coef
        self.max_grad_norm = max_grad_norm
        self.log_dict = {}

        self.set_random_seed(self.seed)
        self.buffer_class = buffer_class
        self.buffer_kwargs = {} if buffer_kwargs is None else buffer_kwargs
        self.buffer = self.buffer_class(
            device=self.device,
            gamma=self.gamma,
            **self.buffer_kwargs,
        )
        self.policy_class = policy_class
        self.policy = self.policy_class(
            self.observation_space, self.action_space, self.learning_rate, **self.policy_kwargs
        )
        self.policy = self.policy.to(self.device)

    def _update_info_buffer(self, info: Dict[str, Any]) -> None:
        # Collect statistics
        assert self.ep_info_buffer is not None

        ep_info = info.get("episode")
        if ep_info is not None:
            self.ep_info_buffer.append(ep_info)

    def set_random_seed(self, seed: Optional[int] = None) -> None:
        if seed is None:
            return
        set_seed_everywhere(seed, using_cuda=self.device.type == torch.device("cuda").type)
        self.action_space.seed(seed)
        self.observation_space.seed(seed)

    def collect_rollouts(
            self,
            env,
            buffer: Buffer,
    ):
        self.policy.set_training_mode(False)
        self._last_obs, _ = self.env.reset()
        self._last_obs = np.array(self._last_obs)
        assert self._last_obs is not None, "No previous observation was provided"

        buffer.reset()
        terminated = False
        while not terminated:
            with torch.no_grad():
                obs_tensor = torch.as_tensor(self._last_obs, device=self.device)
                action = self.policy(obs_tensor.unsqueeze(0))['action']
            action = action.item()
            new_obs, reward, terminated, truncated, info = env.step(action)
            assert not truncated, 'Episode truncation must be off as we want to use Monte Carlo estimation'

            self.num_timesteps += 1
            self._episode_num += int(terminated)
            buffer.add(
                self._last_obs,
                action,
                reward,
            )

            self._last_obs = np.array(new_obs)
            self._update_info_buffer(info)

        buffer.compute_returns()

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        returns = rollout_data.returns

        # Policy gradient loss
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates)
        ])

    def get_current_mean_return(self) -> float:
        if len(self.ep_info_buffer) == 0:
            return -math.inf

        return np.mean(np.concatenate([ep_info["r"] for ep_info in self.ep_info_buffer])).item()

    def _dump_logs(self, iteration: int) -> None:
        assert self.ep_info_buffer is not None

        time_elapsed = max((time.time_ns() - self.start_time) / 1e9, sys.float_info.epsilon)
        fps = int((self.num_timesteps - self._num_timesteps_at_start) / time_elapsed)
        self.log_dict["time/iterations"] = iteration
        if len(self.ep_info_buffer) > 0 and len(self.ep_info_buffer[0]) > 0:
            self.log_dict["rollout/ep_rew_mean"] = self.get_current_mean_return()
            self.log_dict["rollout/ep_len_mean"] = np.mean(
                np.concatenate([ep_info["l"] for ep_info in self.ep_info_buffer])).item()

        self.log_dict["time/fps"] = fps
        self.log_dict["time/time_elapsed"] = int(time_elapsed)
        self.log_dict["global_step"] = self.num_timesteps
        self.log_dict["num_episodes"] = self._episode_num
        print(json.dumps(self.log_dict, sort_keys=True, indent=4))

        if WANDB_IS_AVAILABLE and wandb.run is not None:
            wandb.log(self.log_dict)

    def learn(
            self,
            max_timesteps: int,
            expected_return: float,
            log_interval: int = 1000,
            save_checkpoint_path: str = None,
            save_checkpoint_interval: int = 5000,
    ) -> None:
        assert self.env is not None

        self.start_time = time.time_ns()
        self.num_timesteps = 0
        self._episode_num = 0
        self._num_timesteps_at_start = 0
        log_interval = log_interval or math.inf
        if save_checkpoint_path is None or save_checkpoint_interval is None or not COLAB:
            save_checkpoint_interval = math.inf

        next_log_step = self.num_timesteps + log_interval
        next_save_step = self.num_timesteps + save_checkpoint_interval

        if self._last_obs is None:
            self._last_obs, _ = self.env.reset(seed=self.seed)

        iteration = 0
        while True:
            if self.get_current_mean_return() >= expected_return:
                print('Решено!')
                break

            if self.num_timesteps >= max_timesteps:
                print(f'Задача не решена за {max_timesteps} шагов')
                break

            self.collect_rollouts(self.env, self.buffer, )
            iteration += 1

            if self.num_timesteps >= next_log_step:
                assert self.ep_info_buffer is not None
                self._dump_logs(iteration)
                next_log_step += log_interval

            if self.num_timesteps >= next_save_step:
                next_save_step += save_checkpoint_interval
                checkpoint = {'policy': self.policy.state_dict(), 'optimizer': self.policy.optimizer.state_dict(),
                              'num_timesteps': self.num_timesteps, 'episode_num': self._episode_num,
                              'ep_info_buffer': self.ep_info_buffer}
                os.makedirs(save_checkpoint_path, exist_ok=True)
                torch.save(checkpoint, os.path.join(save_checkpoint_path, 'checkpoint.pt'))

            self.train()

# %%
def run_algorithm(algorithm_class, algorithm_kwargs, use_wandb, wandb_kwargs, learn_kwargs):
    env = make_env()
    model = algorithm_class(env, **algorithm_kwargs)
    if use_wandb:
        config = {}
        config.update(algorithm_kwargs)
        config.update(learn_kwargs)
        config.update(wandb_kwargs.get('config', {}))
        wandb_kwargs['config'] = config
        if wandb.run is not None:
            wandb.finish()

        wandb.init(**wandb_kwargs)

    model.learn(**learn_kwargs)
    if use_wandb:
        wandb.finish()

# %%
run_algorithm(
    algorithm_class=Reinforce,
    algorithm_kwargs=dict(seed=0, device="cpu"),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce', mode='offline'),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                      save_checkpoint_path='./reinforce')
)
# Out:
# Using cpu device
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_4117/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_4117/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1240,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 413.3333333333333,
#     "rollout/ep_rew_mean": -83.91937255859375,
#     "time/fps": 317,
#     "time/iterations": 3,
#     "time/time_elapsed": 3,
#     "train/entropy": 2.0787887573242188,
#     "train/entropy_loss": -0.002078788820654154,
#     "train/grad_norm": 0.0167101938277483,
#     "train/loss": -0.44617414474487305,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.44409534335136414
# }
# {
#     "global_step": 2060,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -79.820068359375,
#     "time/fps": 304,
#     "time/iterations": 5,
#     "time/time_elapsed": 6,
#     "train/entropy": 2.078401565551758,
#     "train/entropy_loss": -0.0020784016232937574,
#     "train/grad_norm": 0.014652862213551998,
#     "train/loss": -0.204746276140213,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.20266787707805634
# }
# {
#     "global_step": 3461,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 494.42857142857144,
#     "rollout/ep_rew_mean": -83.31453704833984,
#     "time/fps": 318,
#     "time/iterations": 7,
#     "time/time_elapsed": 10,
#     "train/entropy": 2.0782716274261475,
#     "train/entropy_loss": -0.0020782717037945986,
#     "train/grad_norm": 0.02190515771508217,
#     "train/loss": -0.5658439993858337,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": -0.5637657046318054
# }
# {
#     "global_step": 4232,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 470.22222222222223,
#     "rollout/ep_rew_mean": -88.19976043701172,
#     "time/fps": 311,
#     "time/iterations": 9,
#     "time/time_elapsed": 13,
#     "train/entropy": 2.077615976333618,
#     "train/entropy_loss": -0.0020776160527020693,
#     "train/grad_norm": 0.036803435534238815,
#     "train/loss": -0.8163237571716309,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.8142461180686951
# }
# {
#     "global_step": 5070,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 463.4,
#     "rollout/ep_rew_mean": -92.11969757080078,
#     "time/fps": 312,
#     "time/iterations": 11,
#     "time/time_elapsed": 16,
#     "train/entropy": 2.0771374702453613,
#     "train/entropy_loss": -0.0020771375857293606,
#     "train/grad_norm": 0.03612349554896355,
#     "train/loss": -0.5624060034751892,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": -0.5603288412094116
# }
# {
#     "global_step": 6127,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 266.6,
#     "rollout/ep_rew_mean": 959.5989990234375,
#     "time/fps": 307,
#     "time/iterations": 17,
#     "time/time_elapsed": 19,
#     "train/entropy": 1.851620982051827e-05,
#     "train/entropy_loss": -1.851621078685639e-08,
#     "train/grad_norm": 0.0007330508669838309,
#     "train/loss": 9.469837095821276e-06,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": 9.488353498454671e-06
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▄▅▆█</td></tr><tr><td>num_episodes</td><td>▁▂▃▄▅█</td></tr><tr><td>rollout/ep_len_mean</td><td>▆▅█▇▇▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁█</td></tr><tr><td>time/fps</td><td>▇▁█▅▅▃</td></tr><tr><td>time/iterations</td><td>▁▂▃▄▅█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▄▅▇█</td></tr><tr><td>train/entropy</td><td>█████▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁█</td></tr><tr><td>train/grad_norm</td><td>▄▄▅██▁</td></tr><tr><td>train/loss</td><td>▄▆▃▁▃█</td></tr><tr><td>train/n_updates</td><td>▁▂▃▄▅█</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▆▃▁▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>6127</td></tr><tr><td>num_episodes</td><td>17</td></tr><tr><td>rollout/ep_len_mean</td><td>266.6</td></tr><tr><td>rollout/ep_rew_mean</td><td>959.599</td></tr><tr><td>time/fps</td><td>307</td></tr><tr><td>time/iterations</td><td>17</td></tr><tr><td>time/time_elapsed</td><td>19</td></tr><tr><td>train/entropy</td><td>2e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.00073</td></tr><tr><td>train/loss</td><td>1e-05</td></tr><tr><td>train/n_updates</td><td>16</td></tr><tr><td>train/policy_gradient_loss</td><td>1e-05</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/RL/practices/prac5/wandb/offline-run-20251024_142012-r05bezkd<code>
# Find logs at: <code>./wandb/offline-run-20251024_142012-r05bezkd/logs</code>

# %% [markdown]
# # 2 REINFORCE с базовым уровнем
# Градиент стратагии зависит от величины отдачи. Однако отдача может быть очень шумной оценкой $Q ^ {\pi} (s, a)$, особенно в средах с отложенными или редкими вознаграждениями. Этот шум приводит к высокой дисперсии в оценках градиента, что влечёт за собой сильные изменения стратегии. При этом обучение становится нестабильным, а сходимость медленной. Одним из способов снижения дисперсии является использование базового уровня $b(s)$. Базовый уровень $b(s)$ не зависит от действий, поэтому вычитание из оценки $Q ^ {\pi} (s, a)$ не приводит к смещению оценки градиента.
#
# $$\nabla_\theta J(\theta) = \mathbb{E}_\pi [(G_t - b(s)) \nabla_\theta \ln \pi_\theta(a_t \vert s_t)]$$
#
# ## 2.1 REINFORCE с необучаемым базовым уровнем (средняя отдача)
# В некоторых случаях в качестве базового уровня достаточно использовать среднюю отдачу за предыдущие эпизоды. Даже такая простая эвристика может помочь стабилизировать процесс обучения на ранних этапах.

# %% [markdown]
# (3 балла)

# %%
# AverageReturnBuffer хранит статистику - среднюю отдачу по всем состояниям и эпизодам за время обучения
class AverageReturnBuffer(Buffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        # Дополнительные переменные, необходимые для вычисления средней отдачи
        self.total_returns = 0.0
        self.num_episodes = 0

    def get_average_return(self):
        # Избегаем деления на ноль, если эпизодов еще не было
        if self.num_episodes == 0:
            return 0.0
        return self.total_returns / self.num_episodes

    def compute_returns(self) -> None:
        # Сначала вычисляем отдачи G_t для текущей траектории,
        # вызывая метод родительского класса
        super().compute_returns()

        # Обновляем статистику средней отдачи
        # self.returns[0] - это G_0, полная отдача за собранный эпизод
        if self.size() > 0:
            self.total_returns += self.returns[0]
            self.num_episodes += 1

# %% [markdown]
# (1 балл)

# %%
class AverageReturnBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[AverageReturnBuffer] = AverageReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda"):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']

        # Получаем среднюю отдачу
        # self.buffer является экземпляром AverageReturnBuffer
        baseline = self.buffer.get_average_return()

        # Посчитать отдачи с учётом базового уровня (Advantage)
        # A(s_t, a_t) = G_t - b(s_t)
        # В данном случае b(s_t) - это константа (средняя отдача)
        returns = rollout_data.returns - baseline

        # Policy gradient loss (теперь взвешен на advantage)
        policy_loss = -(returns * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        loss = policy_loss + entropy_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        # Логируем baseline
        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %%
run_algorithm(
    algorithm_class=AverageReturnBaselineReinforce,
    algorithm_kwargs=dict(seed=0, device="cpu"),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_simple-baseline', mode="offline"),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='./reinforce_simple-baseline')
)
# Out:
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cpu device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_4117/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_4117/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1240,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 413.3333333333333,
#     "rollout/ep_rew_mean": -83.91937255859375,
#     "time/fps": 306,
#     "time/iterations": 3,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.030910199562462874,
#     "train/entropy": 2.078827381134033,
#     "train/entropy_loss": -0.0020788274705410004,
#     "train/grad_norm": 0.015689808875322342,
#     "train/loss": -0.3819219470024109,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": -0.3798431158065796
# }
# {
#     "global_step": 2060,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -78.0874252319336,
#     "time/fps": 298,
#     "time/iterations": 5,
#     "time/time_elapsed": 6,
#     "train/baseline": 0.010780641458486609,
#     "train/entropy": 2.0784900188446045,
#     "train/entropy_loss": -0.002078490098938346,
#     "train/grad_norm": 0.013824238441884518,
#     "train/loss": -0.2413625419139862,
#     "train/n_updates": 4,
#     "train/policy_gradient_loss": -0.23928405344486237
# }
# {
#     "global_step": 3311,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 413.875,
#     "rollout/ep_rew_mean": -81.0667724609375,
#     "time/fps": 306,
#     "time/iterations": 8,
#     "time/time_elapsed": 10,
#     "train/baseline": 0.017218618799771372,
#     "train/entropy": 2.077608585357666,
#     "train/entropy_loss": -0.0020776086021214724,
#     "train/grad_norm": 0.023770421743392944,
#     "train/loss": -0.286199152469635,
#     "train/n_updates": 7,
#     "train/policy_gradient_loss": -0.2841215431690216
# }
# {
#     "global_step": 4017,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 401.7,
#     "rollout/ep_rew_mean": -77.12593078613281,
#     "time/fps": 302,
#     "time/iterations": 10,
#     "time/time_elapsed": 13,
#     "train/baseline": 0.005467117313533444,
#     "train/entropy": 2.038917064666748,
#     "train/entropy_loss": -0.0020389172714203596,
#     "train/grad_norm": 0.03150786831974983,
#     "train/loss": -0.4543097913265228,
#     "train/n_updates": 9,
#     "train/policy_gradient_loss": -0.45227086544036865
# }
# {
#     "global_step": 5157,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 273.3,
#     "rollout/ep_rew_mean": 968.4656372070312,
#     "time/fps": 303,
#     "time/iterations": 16,
#     "time/time_elapsed": 16,
#     "train/baseline": 1.7212493502341373,
#     "train/entropy": 6.046840326234815e-07,
#     "train/entropy_loss": -6.046840805851161e-10,
#     "train/grad_norm": 2.741705066000577e-05,
#     "train/loss": -6.046840805851161e-10,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": -0.0
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▂▅▆█</td></tr><tr><td>num_episodes</td><td>▁▂▄▅█</td></tr><tr><td>rollout/ep_len_mean</td><td>███▇▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁█</td></tr><tr><td>time/fps</td><td>█▁█▅▅</td></tr><tr><td>time/iterations</td><td>▁▂▄▅█</td></tr><tr><td>time/time_elapsed</td><td>▁▂▅▆█</td></tr><tr><td>train/baseline</td><td>▁▁▁▁█</td></tr><tr><td>train/entropy</td><td>████▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁█</td></tr><tr><td>train/grad_norm</td><td>▄▄▆█▁</td></tr><tr><td>train/loss</td><td>▂▄▄▁█</td></tr><tr><td>train/n_updates</td><td>▁▂▄▅█</td></tr><tr><td>train/policy_gradient_loss</td><td>▂▄▄▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>5157</td></tr><tr><td>num_episodes</td><td>16</td></tr><tr><td>rollout/ep_len_mean</td><td>273.3</td></tr><tr><td>rollout/ep_rew_mean</td><td>968.46564</td></tr><tr><td>time/fps</td><td>303</td></tr><tr><td>time/iterations</td><td>16</td></tr><tr><td>time/time_elapsed</td><td>16</td></tr><tr><td>train/baseline</td><td>1.72125</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>3e-05</td></tr><tr><td>train/loss</td><td>-0.0</td></tr><tr><td>train/n_updates</td><td>15</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/RL/practices/prac5/wandb/offline-run-20251024_142036-kt4qjmjj<code>
# Find logs at: <code>./wandb/offline-run-20251024_142036-kt4qjmjj/logs</code>

# %% [markdown]
# ## 2.2 REINFORCE с обучаемым базовым уровнем
# Чаще всего в качестве базового уровня применяется оценка функции полезности состояний $b(s) = v(s) = \mathbb{E}[G_t| s_t = s]$, получаемая с помощью нейросетевой аппроксимации. При этом величину $G_t - b(s_t)$ можно рассматривать как оценку функции преимущества (advantage) действия $a_t$ в состоянии $s_t$: $A(s_t, a_t) = Q(s_t, a_t) - V(s_t)$.
#
# #### Shared-encoder
# Модели стратегии и функции полезности могут обучаться в разных режимах — стратегия только on-policy (шаг обучения на текущей собранной подтраектории), а полезность on-policy или off-policy (шаг обучения на текущей подтраектории или на батче из replay buffer). Это с одной стороны привносит гибкость в обучение, с другой — усложняет его.
#
# Если обе модели обучаются on-policy, то имеет смысл объединить их сетки в одну и делать общий шаг обратного распространения ошибки. Однако, если они обучаются в разных режимах (и с разной частотой обновления), то велика вероятность, что их шаги обучения могут начать конфликтовать в случае общего тела — для такого варианта намного предпочтительнее разделить их на разные подсети (либо аккуратно настраивать гиперпарметры, чтобы стабилизировать обучение). В целом, рекомендуется использовать общий энкодер наблюдений, а далее как можно скорее разделять головы.

# %% [markdown]
# (2 балла)

# %%
class ValuePolicy(ReinforcePolicy):
    def __init__(self, observation_space: gym.Space, action_space: gym.Space, lr: float,
                 optimizer_class: Type[torch.optim.Optimizer] = torch.optim.RMSprop,
                 optimizer_kwargs: Dict[str, Any] = {'eps': 1e-5}):
        
        # Сначала инициализируем родительский класс (который создает
        # features_extractor, action_net и optimizer ТОЛЬКО для них)
        super().__init__(observation_space, action_space, lr, optimizer_class, optimizer_kwargs)

        # Добавить слой для вычисления полезности состояний
        # Он использует те же features, что и action_net
        self.value_net = nn.Linear(self.features_extractor.features_dim, 1)
        
        # ВАЖНО: Оптимизатор родительского класса был создан ДО self.value_net.
        # Нам нужно пересоздать оптимизатор, чтобы он "знал"
        # о параметрах value_net и тоже их обучал.
        self.optimizer = self.optimizer_class(self.parameters(), lr=self.lr, **self.optimizer_kwargs)


    def evaluate_actions(self, obs: torch.Tensor, actions_taken: torch.Tensor) -> Dict[str, torch.Tensor]:
        # Используем features_extractor из родительского класса
        features = self.extract_features(obs)
        
        # Policy head (логика из родительского класса)
        action_logits = self.action_net(features)
        distribution = Categorical(logits=action_logits)
        log_prob = distribution.log_prob(actions_taken)
        entropy = distribution.entropy()
        
        # Value head
        # Вычисляем V(s)
        values = self.value_net(features).squeeze(-1) # .squeeze(-1) чтобы (B, 1) -> (B,)

        # Метод должен возвращать словарь с 'features', 'log_prob', 'entropy' и 'value' (в ед. числе, как в ValueBaselineReinforce)
        return {'features': features, 'log_prob': log_prob, 'entropy': entropy, 'value': values}

# %% [markdown]
# (1 балл)

# %%
class ValueBaselineReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ValuePolicy] = ValuePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[Buffer] = Buffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", vf_coef: float = 0.5,):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class,
                         policy_kwargs, buffer_class, buffer_kwargs, seed, device)
        self.vf_coef = vf_coef

    def train(self) -> None:
        self.policy.set_training_mode(True)

        rollout_data = self.buffer.get()
        actions = rollout_data.actions.long()
        # self.policy теперь экземпляр ValuePolicy
        policy_output = self.policy.evaluate_actions(rollout_data.observations, actions)
        log_prob = policy_output['log_prob']
        entropy = policy_output['entropy']
        values = policy_output['value'] # Оценка V(s_t) из нейросети
        
        # G_t
        returns = rollout_data.returns

        # Advantage A(s_t, a_t) = G_t - V(s_t)
        # .detach() нужен, чтобы градиенты от policy_loss не "портили"
        # обучение value_net. Value_net должен обучаться только на value_loss.
        advantages = returns - values.detach()
        baseline = values.mean().item()

        # Policy gradient loss (на основе advantage)
        policy_loss = -(advantages * log_prob).mean()

        # Entropy loss
        entropy = torch.mean(entropy)
        entropy_loss = -self.ent_coef * entropy

        # Value loss с коэффициентом self.vf_coef
        # Обучаем V(s_t) (values) предсказывать G_t (returns)
        # Используем Mean Squared Error (MSE)
        value_loss = F.mse_loss(values, returns) * self.vf_coef

        # Суммарная ошибка
        loss = policy_loss + entropy_loss + value_loss

        # Optimization step
        self.policy.optimizer.zero_grad()
        loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
        self.policy.optimizer.step()

        self._n_updates += 1

        # Логируем value_loss и baseline
        self.log_dict = dict([
            ("train/entropy_loss", entropy_loss.item()), ("train/entropy", entropy.item()),
            ("train/policy_gradient_loss", policy_loss.item()), ("train/loss", loss.item()),
            ("train/grad_norm", grad_norm.item()), ("train/n_updates", self._n_updates),
            ("train/baseline", baseline), ("train/value_loss", value_loss.item())
        ])

# %%
run_algorithm(
    algorithm_class=ValueBaselineReinforce,
    algorithm_kwargs=dict(seed=0, device="cpu"),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_value-baseline', mode="offline"),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='./reinforce_value-baseline')
)
# Out:
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cpu device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_4117/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_4117/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1195,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 398.3333333333333,
#     "rollout/ep_rew_mean": -90.7602310180664,
#     "time/fps": 325,
#     "time/iterations": 3,
#     "time/time_elapsed": 3,
#     "train/baseline": -0.2890280485153198,
#     "train/entropy": 2.078861951828003,
#     "train/entropy_loss": -0.002078862162306905,
#     "train/grad_norm": 0.1267189383506775,
#     "train/loss": 0.1294935792684555,
#     "train/n_updates": 2,
#     "train/policy_gradient_loss": 0.09813863039016724,
#     "train/value_loss": 0.033433813601732254
# }
# {
#     "global_step": 2475,
#     "num_episodes": 4,
#     "rollout/ep_len_mean": 618.75,
#     "rollout/ep_rew_mean": -95.22286987304688,
#     "time/fps": 333,
#     "time/iterations": 4,
#     "time/time_elapsed": 7,
#     "train/baseline": -0.07829532772302628,
#     "train/entropy": 2.079209089279175,
#     "train/entropy_loss": -0.002079209079965949,
#     "train/grad_norm": 0.10164773464202881,
#     "train/loss": -0.12018004804849625,
#     "train/n_updates": 3,
#     "train/policy_gradient_loss": -0.1461765468120575,
#     "train/value_loss": 0.028075704351067543
# }
# {
#     "global_step": 3572,
#     "num_episodes": 6,
#     "rollout/ep_len_mean": 595.3333333333334,
#     "rollout/ep_rew_mean": -65.1932601928711,
#     "time/fps": 319,
#     "time/iterations": 6,
#     "time/time_elapsed": 11,
#     "train/baseline": -0.06489953398704529,
#     "train/entropy": 2.0792391300201416,
#     "train/entropy_loss": -0.0020792391151189804,
#     "train/grad_norm": 0.10132763534784317,
#     "train/loss": -0.10390180349349976,
#     "train/n_updates": 5,
#     "train/policy_gradient_loss": -0.16244016587734222,
#     "train/value_loss": 0.0606175996363163
# }
# {
#     "global_step": 4387,
#     "num_episodes": 7,
#     "rollout/ep_len_mean": 626.7142857142857,
#     "rollout/ep_rew_mean": -59.06100082397461,
#     "time/fps": 321,
#     "time/iterations": 7,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.10314425081014633,
#     "train/entropy": 2.0792763233184814,
#     "train/entropy_loss": -0.002079276368021965,
#     "train/grad_norm": 0.3096586763858795,
#     "train/loss": 0.5417556762695312,
#     "train/n_updates": 6,
#     "train/policy_gradient_loss": 0.4632226824760437,
#     "train/value_loss": 0.08061224222183228
# }
# {
#     "global_step": 5243,
#     "num_episodes": 9,
#     "rollout/ep_len_mean": 582.5555555555555,
#     "rollout/ep_rew_mean": -66.35262298583984,
#     "time/fps": 318,
#     "time/iterations": 9,
#     "time/time_elapsed": 16,
#     "train/baseline": -0.031153332442045212,
#     "train/entropy": 2.0793073177337646,
#     "train/entropy_loss": -0.002079307334497571,
#     "train/grad_norm": 0.31213316321372986,
#     "train/loss": -0.5193012952804565,
#     "train/n_updates": 8,
#     "train/policy_gradient_loss": -0.5913278460502625,
#     "train/value_loss": 0.07410586625337601
# }
# {
#     "global_step": 6904,
#     "num_episodes": 11,
#     "rollout/ep_len_mean": 656.1,
#     "rollout/ep_rew_mean": -50.79778289794922,
#     "time/fps": 322,
#     "time/iterations": 11,
#     "time/time_elapsed": 21,
#     "train/baseline": -0.09783618897199631,
#     "train/entropy": 2.0790882110595703,
#     "train/entropy_loss": -0.0020790882408618927,
#     "train/grad_norm": 0.018628312274813652,
#     "train/loss": 0.0735502764582634,
#     "train/n_updates": 10,
#     "train/policy_gradient_loss": 0.00962319690734148,
#     "train/value_loss": 0.06600616872310638
# }
# {
#     "global_step": 7283,
#     "num_episodes": 12,
#     "rollout/ep_len_mean": 660.4,
#     "rollout/ep_rew_mean": -49.61639404296875,
#     "time/fps": 316,
#     "time/iterations": 12,
#     "time/time_elapsed": 22,
#     "train/baseline": -0.09828976541757584,
#     "train/entropy": 2.0790042877197266,
#     "train/entropy_loss": -0.0020790044218301773,
#     "train/grad_norm": 0.17066898941993713,
#     "train/loss": 0.3095276951789856,
#     "train/n_updates": 11,
#     "train/policy_gradient_loss": 0.26697519421577454,
#     "train/value_loss": 0.04463151842355728
# }
# {
#     "global_step": 8101,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 690.6,
#     "rollout/ep_rew_mean": -39.27075958251953,
#     "time/fps": 318,
#     "time/iterations": 13,
#     "time/time_elapsed": 25,
#     "train/baseline": -0.05983874201774597,
#     "train/entropy": 2.0791468620300293,
#     "train/entropy_loss": -0.0020791469141840935,
#     "train/grad_norm": 0.1642789989709854,
#     "train/loss": -0.2623816728591919,
#     "train/n_updates": 12,
#     "train/policy_gradient_loss": -0.2924961447715759,
#     "train/value_loss": 0.0321936160326004
# }
# {
#     "global_step": 9708,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 673.1,
#     "rollout/ep_rew_mean": -20.53598403930664,
#     "time/fps": 319,
#     "time/iterations": 15,
#     "time/time_elapsed": 30,
#     "train/baseline": -0.06172143667936325,
#     "train/entropy": 2.0790908336639404,
#     "train/entropy_loss": -0.0020790910348296165,
#     "train/grad_norm": 0.20424306392669678,
#     "train/loss": -0.2821483612060547,
#     "train/n_updates": 14,
#     "train/policy_gradient_loss": -0.3479814827442169,
#     "train/value_loss": 0.06791222840547562
# }
# {
#     "global_step": 10109,
#     "num_episodes": 16,
#     "rollout/ep_len_mean": 653.7,
#     "rollout/ep_rew_mean": -36.67254638671875,
#     "time/fps": 311,
#     "time/iterations": 16,
#     "time/time_elapsed": 32,
#     "train/baseline": -0.09308606386184692,
#     "train/entropy": 2.0786726474761963,
#     "train/entropy_loss": -0.0020786726381629705,
#     "train/grad_norm": 0.23195046186447144,
#     "train/loss": 0.42674148082733154,
#     "train/n_updates": 15,
#     "train/policy_gradient_loss": 0.3722803592681885,
#     "train/value_loss": 0.05653980374336243
# }
# {
#     "global_step": 11052,
#     "num_episodes": 17,
#     "rollout/ep_len_mean": 666.5,
#     "rollout/ep_rew_mean": -37.9742317199707,
#     "time/fps": 313,
#     "time/iterations": 17,
#     "time/time_elapsed": 35,
#     "train/baseline": -0.05819415673613548,
#     "train/entropy": 2.0789337158203125,
#     "train/entropy_loss": -0.00207893387414515,
#     "train/grad_norm": 0.23576892912387848,
#     "train/loss": -0.3656725585460663,
#     "train/n_updates": 16,
#     "train/policy_gradient_loss": -0.41916796565055847,
#     "train/value_loss": 0.055574335157871246
# }
# {
#     "global_step": 12626,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 689.8,
#     "rollout/ep_rew_mean": -27.435077667236328,
#     "time/fps": 311,
#     "time/iterations": 20,
#     "time/time_elapsed": 40,
#     "train/baseline": -0.08929786831140518,
#     "train/entropy": 2.0781657695770264,
#     "train/entropy_loss": -0.002078165765851736,
#     "train/grad_norm": 0.03915197029709816,
#     "train/loss": -0.029924727976322174,
#     "train/n_updates": 19,
#     "train/policy_gradient_loss": -0.05987778678536415,
#     "train/value_loss": 0.03203122317790985
# }
# {
#     "global_step": 13062,
#     "num_episodes": 21,
#     "rollout/ep_len_mean": 615.8,
#     "rollout/ep_rew_mean": -41.69874954223633,
#     "time/fps": 309,
#     "time/iterations": 21,
#     "time/time_elapsed": 42,
#     "train/baseline": -0.09501630067825317,
#     "train/entropy": 2.0781545639038086,
#     "train/entropy_loss": -0.0020781545899808407,
#     "train/grad_norm": 0.06570541113615036,
#     "train/loss": 0.1562526971101761,
#     "train/n_updates": 20,
#     "train/policy_gradient_loss": 0.10312140733003616,
#     "train/value_loss": 0.0552094429731369
# }
# {
#     "global_step": 14051,
#     "num_episodes": 24,
#     "rollout/ep_len_mean": 538.5,
#     "rollout/ep_rew_mean": -51.128883361816406,
#     "time/fps": 310,
#     "time/iterations": 24,
#     "time/time_elapsed": 45,
#     "train/baseline": -0.1767883598804474,
#     "train/entropy": 2.0755932331085205,
#     "train/entropy_loss": -0.0020755932200700045,
#     "train/grad_norm": 0.3839137852191925,
#     "train/loss": -0.35937124490737915,
#     "train/n_updates": 23,
#     "train/policy_gradient_loss": -0.42764389514923096,
#     "train/value_loss": 0.07034821808338165
# }
# {
#     "global_step": 15017,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 396.5,
#     "rollout/ep_rew_mean": -65.4103012084961,
#     "time/fps": 310,
#     "time/iterations": 27,
#     "time/time_elapsed": 48,
#     "train/baseline": -0.16358882188796997,
#     "train/entropy": 2.0744872093200684,
#     "train/entropy_loss": -0.0020744872745126486,
#     "train/grad_norm": 0.02554333768785,
#     "train/loss": 0.06899247318506241,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": 0.02809111401438713,
#     "train/value_loss": 0.04297584667801857
# }
# {
#     "global_step": 16165,
#     "num_episodes": 32,
#     "rollout/ep_len_mean": 275.1,
#     "rollout/ep_rew_mean": -51.99273681640625,
#     "time/fps": 309,
#     "time/iterations": 32,
#     "time/time_elapsed": 52,
#     "train/baseline": -0.42170250415802,
#     "train/entropy": 2.0518503189086914,
#     "train/entropy_loss": -0.002051850315183401,
#     "train/grad_norm": 1.3543376922607422,
#     "train/loss": 1.0340501070022583,
#     "train/n_updates": 31,
#     "train/policy_gradient_loss": 0.8576467633247375,
#     "train/value_loss": 0.1784552037715912
# }
# {
#     "global_step": 17141,
#     "num_episodes": 35,
#     "rollout/ep_len_mean": 277.3,
#     "rollout/ep_rew_mean": -52.751708984375,
#     "time/fps": 310,
#     "time/iterations": 35,
#     "time/time_elapsed": 55,
#     "train/baseline": -0.19223050773143768,
#     "train/entropy": 2.0687100887298584,
#     "train/entropy_loss": -0.0020687102805823088,
#     "train/grad_norm": 0.02650926634669304,
#     "train/loss": -0.0008171536028385162,
#     "train/n_updates": 34,
#     "train/policy_gradient_loss": -0.025614747777581215,
#     "train/value_loss": 0.026866303756833076
# }
# {
#     "global_step": 18139,
#     "num_episodes": 39,
#     "rollout/ep_len_mean": 266.7,
#     "rollout/ep_rew_mean": -34.48932647705078,
#     "time/fps": 309,
#     "time/iterations": 39,
#     "time/time_elapsed": 58,
#     "train/baseline": -0.16557934880256653,
#     "train/entropy": 2.06738543510437,
#     "train/entropy_loss": -0.0020673854742199183,
#     "train/grad_norm": 0.05953098461031914,
#     "train/loss": 0.050342850387096405,
#     "train/n_updates": 38,
#     "train/policy_gradient_loss": -0.0016946815885603428,
#     "train/value_loss": 0.054104916751384735
# }
# {
#     "global_step": 19003,
#     "num_episodes": 42,
#     "rollout/ep_len_mean": 283.8,
#     "rollout/ep_rew_mean": -23.21815299987793,
#     "time/fps": 309,
#     "time/iterations": 42,
#     "time/time_elapsed": 61,
#     "train/baseline": -0.17060883343219757,
#     "train/entropy": 2.065687656402588,
#     "train/entropy_loss": -0.0020656876731663942,
#     "train/grad_norm": 0.08113908767700195,
#     "train/loss": 0.16404075920581818,
#     "train/n_updates": 41,
#     "train/policy_gradient_loss": 0.09617967158555984,
#     "train/value_loss": 0.06992677599191666
# }
# {
#     "global_step": 20007,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 286.6,
#     "rollout/ep_rew_mean": -6.706178188323975,
#     "time/fps": 309,
#     "time/iterations": 45,
#     "time/time_elapsed": 64,
#     "train/baseline": -0.1573597639799118,
#     "train/entropy": 2.061171293258667,
#     "train/entropy_loss": -0.00206117145717144,
#     "train/grad_norm": 0.19137434661388397,
#     "train/loss": 0.31358176469802856,
#     "train/n_updates": 44,
#     "train/policy_gradient_loss": 0.23561179637908936,
#     "train/value_loss": 0.0800311341881752
# }
# {
#     "global_step": 21248,
#     "num_episodes": 48,
#     "rollout/ep_len_mean": 337.8,
#     "rollout/ep_rew_mean": 7.367408752441406,
#     "time/fps": 309,
#     "time/iterations": 48,
#     "time/time_elapsed": 68,
#     "train/baseline": -0.10559568554162979,
#     "train/entropy": 2.064279079437256,
#     "train/entropy_loss": -0.002064279280602932,
#     "train/grad_norm": 0.2552332580089569,
#     "train/loss": -0.29601338505744934,
#     "train/n_updates": 47,
#     "train/policy_gradient_loss": -0.3347974121570587,
#     "train/value_loss": 0.04084831848740578
# }
# {
#     "global_step": 22295,
#     "num_episodes": 51,
#     "rollout/ep_len_mean": 366.8,
#     "rollout/ep_rew_mean": 4.282885551452637,
#     "time/fps": 309,
#     "time/iterations": 51,
#     "time/time_elapsed": 72,
#     "train/baseline": -0.06378668546676636,
#     "train/entropy": 2.06618332862854,
#     "train/entropy_loss": -0.0020661833696067333,
#     "train/grad_norm": 0.08121607452630997,
#     "train/loss": -0.05888763815164566,
#     "train/n_updates": 50,
#     "train/policy_gradient_loss": -0.12049873173236847,
#     "train/value_loss": 0.06367727369070053
# }
# {
#     "global_step": 23089,
#     "num_episodes": 54,
#     "rollout/ep_len_mean": 346.4,
#     "rollout/ep_rew_mean": 10.864709854125977,
#     "time/fps": 309,
#     "time/iterations": 54,
#     "time/time_elapsed": 74,
#     "train/baseline": -0.10731466859579086,
#     "train/entropy": 2.061821699142456,
#     "train/entropy_loss": -0.0020618217531591654,
#     "train/grad_norm": 0.055919796228408813,
#     "train/loss": -0.018880072981119156,
#     "train/n_updates": 53,
#     "train/policy_gradient_loss": -0.06072946637868881,
#     "train/value_loss": 0.04391121491789818
# }
# {
#     "global_step": 24351,
#     "num_episodes": 58,
#     "rollout/ep_len_mean": 310.3,
#     "rollout/ep_rew_mean": 43.32095718383789,
#     "time/fps": 309,
#     "time/iterations": 58,
#     "time/time_elapsed": 78,
#     "train/baseline": -0.025755351409316063,
#     "train/entropy": 2.062852144241333,
#     "train/entropy_loss": -0.0020628522615879774,
#     "train/grad_norm": 0.5496393442153931,
#     "train/loss": 0.9698413014411926,
#     "train/n_updates": 57,
#     "train/policy_gradient_loss": 0.7814691066741943,
#     "train/value_loss": 0.19043506681919098
# }
# {
#     "global_step": 25206,
#     "num_episodes": 61,
#     "rollout/ep_len_mean": 291.1,
#     "rollout/ep_rew_mean": 62.506324768066406,
#     "time/fps": 309,
#     "time/iterations": 61,
#     "time/time_elapsed": 81,
#     "train/baseline": 0.02211126685142517,
#     "train/entropy": 2.059420108795166,
#     "train/entropy_loss": -0.0020594201050698757,
#     "train/grad_norm": 0.07256114482879639,
#     "train/loss": -0.0016674399375915527,
#     "train/n_updates": 60,
#     "train/policy_gradient_loss": -0.08168284595012665,
#     "train/value_loss": 0.08207482844591141
# }
# {
#     "global_step": 26154,
#     "num_episodes": 64,
#     "rollout/ep_len_mean": 306.5,
#     "rollout/ep_rew_mean": 53.32782745361328,
#     "time/fps": 308,
#     "time/iterations": 64,
#     "time/time_elapsed": 84,
#     "train/baseline": 0.020189853385090828,
#     "train/entropy": 2.05595326423645,
#     "train/entropy_loss": -0.0020559532567858696,
#     "train/grad_norm": 0.3178553283214569,
#     "train/loss": -0.3593325614929199,
#     "train/n_updates": 63,
#     "train/policy_gradient_loss": -0.43236514925956726,
#     "train/value_loss": 0.07508854568004608
# }
# {
#     "global_step": 27041,
#     "num_episodes": 68,
#     "rollout/ep_len_mean": 269.0,
#     "rollout/ep_rew_mean": 20.375120162963867,
#     "time/fps": 308,
#     "time/iterations": 68,
#     "time/time_elapsed": 87,
#     "train/baseline": -0.02132011391222477,
#     "train/entropy": 2.0355756282806396,
#     "train/entropy_loss": -0.0020355756860226393,
#     "train/grad_norm": 0.21103860437870026,
#     "train/loss": -0.22563046216964722,
#     "train/n_updates": 67,
#     "train/policy_gradient_loss": -0.2577192485332489,
#     "train/value_loss": 0.03412436693906784
# }
# {
#     "global_step": 28308,
#     "num_episodes": 72,
#     "rollout/ep_len_mean": 284.9,
#     "rollout/ep_rew_mean": 114.3823013305664,
#     "time/fps": 308,
#     "time/iterations": 72,
#     "time/time_elapsed": 91,
#     "train/baseline": -0.04294366389513016,
#     "train/entropy": 2.0126569271087646,
#     "train/entropy_loss": -0.0020126570016145706,
#     "train/grad_norm": 0.18734771013259888,
#     "train/loss": 0.2712410092353821,
#     "train/n_updates": 71,
#     "train/policy_gradient_loss": 0.19315411150455475,
#     "train/value_loss": 0.08009956032037735
# }
# {
#     "global_step": 29037,
#     "num_episodes": 75,
#     "rollout/ep_len_mean": 266.3,
#     "rollout/ep_rew_mean": 166.8624267578125,
#     "time/fps": 308,
#     "time/iterations": 75,
#     "time/time_elapsed": 94,
#     "train/baseline": 0.006120489910244942,
#     "train/entropy": 1.9941014051437378,
#     "train/entropy_loss": -0.0019941015634685755,
#     "train/grad_norm": 1.3103818893432617,
#     "train/loss": 1.619649052619934,
#     "train/n_updates": 74,
#     "train/policy_gradient_loss": 1.2735371589660645,
#     "train/value_loss": 0.3481059968471527
# }
# {
#     "global_step": 30099,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 285.6,
#     "rollout/ep_rew_mean": 298.6835021972656,
#     "time/fps": 308,
#     "time/iterations": 79,
#     "time/time_elapsed": 97,
#     "train/baseline": 0.1600225418806076,
#     "train/entropy": 1.9501787424087524,
#     "train/entropy_loss": -0.0019501788774505258,
#     "train/grad_norm": 2.222522735595703,
#     "train/loss": 1.9882603883743286,
#     "train/n_updates": 78,
#     "train/policy_gradient_loss": 1.4908267259597778,
#     "train/value_loss": 0.4993837773799896
# }
# {
#     "global_step": 31126,
#     "num_episodes": 85,
#     "rollout/ep_len_mean": 208.9,
#     "rollout/ep_rew_mean": 861.6500244140625,
#     "time/fps": 308,
#     "time/iterations": 85,
#     "time/time_elapsed": 100,
#     "train/baseline": 3.9288315773010254,
#     "train/entropy": 0.018923107534646988,
#     "train/entropy_loss": -1.892310865514446e-05,
#     "train/grad_norm": 146.8498077392578,
#     "train/loss": 10.891118049621582,
#     "train/n_updates": 84,
#     "train/policy_gradient_loss": 0.2554194927215576,
#     "train/value_loss": 10.635717391967773
# }
# {
#     "global_step": 32116,
#     "num_episodes": 91,
#     "rollout/ep_len_mean": 169.6,
#     "rollout/ep_rew_mean": 1889.275634765625,
#     "time/fps": 307,
#     "time/iterations": 91,
#     "time/time_elapsed": 104,
#     "train/baseline": 9.267439842224121,
#     "train/entropy": 3.998790998593904e-05,
#     "train/entropy_loss": -3.998791342496588e-08,
#     "train/grad_norm": 16.139982223510742,
#     "train/loss": 0.3779105842113495,
#     "train/n_updates": 90,
#     "train/policy_gradient_loss": -6.751596401954885e-07,
#     "train/value_loss": 0.3779112994670868
# }
# Решено!
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>▄▇▇▇▇███████▇▆▄▂▂▂▃▃▃▄▃▃▃▃▂▃▂▃▂▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▂▂▂▄█</td></tr><tr><td>time/fps</td><td>▆█▄▅▄▅▃▄▄▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇██</td></tr><tr><td>time/time_elapsed</td><td>▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▄█</td></tr><tr><td>train/entropy</td><td>██████████████████████████████▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁██</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▂</td></tr><tr><td>train/loss</td><td>▁▁▁▂▁▁▂▁▁▂▁▁▁▁▁▂▁▁▁▂▁▁▁▂▁▁▁▁▂▃█▂</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇██</td></tr><tr><td>train/policy_gradient_loss</td><td>▃▂▂▅▁▃▄▂▂▄▂▃▃▂▃▆▃▃▃▄▂▃▃▆▃▂▂▄▇█▄▃</td></tr><tr><td>train/value_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>32116</td></tr><tr><td>num_episodes</td><td>91</td></tr><tr><td>rollout/ep_len_mean</td><td>169.6</td></tr><tr><td>rollout/ep_rew_mean</td><td>1889.27563</td></tr><tr><td>time/fps</td><td>307</td></tr><tr><td>time/iterations</td><td>91</td></tr><tr><td>time/time_elapsed</td><td>104</td></tr><tr><td>train/baseline</td><td>9.26744</td></tr><tr><td>train/entropy</td><td>4e-05</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>16.13998</td></tr><tr><td>train/loss</td><td>0.37791</td></tr><tr><td>train/n_updates</td><td>90</td></tr><tr><td>train/policy_gradient_loss</td><td>-0.0</td></tr><tr><td>train/value_loss</td><td>0.37791</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/RL/practices/prac5/wandb/offline-run-20251024_142058-yre2j57e<code>
# Find logs at: <code>./wandb/offline-run-20251024_142058-yre2j57e/logs</code>

# %% [markdown]
# # 3 REINFORCE с разбиением на мини-батчи
# В предыдущих реализациях по данным одной собранной траетории стратегия обновлялась только один раз. Попробуем разбить траекторию на мини-батчи и обучаться на одной траектории в течение нескольких эпох. С одной стороны это должно привести к ускорению обучения, поскольку модели будут обновляться чаще. С другой стороны такая схема обучения отходит от on-policy режима.

# %%
class BatchedReturnBuffer(AverageReturnBuffer):
    def __init__(self, gamma: float = 0.99, device: Union[torch.device, str] = "cpu"):
        super().__init__(gamma, device)
        self.generator_ready = None

    def reset(self) -> None:
        super().reset()
        self.generator_ready = False

    def get(self, batch_size: Optional[Union[int, float]] = None) -> Generator[BufferSamples, None, None]:
        buffer_size = self.size()
        indices = np.random.permutation(buffer_size)
        if not self.generator_ready:
            self.observations = np.asarray(self.observations)
            self.actions = np.asarray(self.actions)
            self.returns = np.asarray(self.returns, dtype=np.float32)
            self.generator_ready = True

        if batch_size is None or math.isinf(batch_size):
            batch_size = buffer_size

        start_idx = 0
        while start_idx < buffer_size:
            yield self._get_samples(indices[start_idx: start_idx + batch_size])
            start_idx += batch_size

# %% [markdown]
# (3 балла)

# %%
class BatchedAverageReturnReinforce(Reinforce):
    def __init__(self, env: gym.Env, learning_rate: float = 2.5e-4, gamma: float = 0.99, ent_coef: float = 0.001,
                 max_grad_norm: float = 0.5, stats_window_size: int = 10, policy_class: Type[ReinforcePolicy] = ReinforcePolicy,
                 policy_kwargs: Optional[Dict[str, Any]] = None, buffer_class: Type[BatchedReturnBuffer] = BatchedReturnBuffer,
                 buffer_kwargs: Optional[Dict[str, Any]] = None, seed: Optional[int] = None,
                 device: Union[torch.device, str] = "cuda", batch_size: Union[int, float] = 64, n_epochs: int = 1):
        super().__init__(env, learning_rate, gamma, ent_coef, max_grad_norm, stats_window_size, policy_class, policy_kwargs,
                         buffer_class, buffer_kwargs, seed, device)
        self.batch_size = int(batch_size) # Убедимся, что batch_size - это int
        self.n_epochs = n_epochs

    def train(self) -> None:
        self.policy.set_training_mode(True)
        
        # Получаем базовый уровень (среднюю отдачу) ОДИН раз для всей траектории
        # self.buffer - экземпляр BatchedReturnBuffer, который наследуется от AverageReturnBuffer
        baseline = self.buffer.get_average_return()

        # Списки для сбора статистики по всем батчам и эпохам
        all_policy_losses, all_entropies, all_entropy_losses, all_losses, all_grad_norms = [], [], [], [], []
        
        # В train выполняется self.n_epochs проходов по буферу.
        for epoch in range(self.n_epochs):
            # Данные из буфера сэмплируются батчами размера self.batch_size
            # self.buffer.get() теперь является генератором
            for batch_data in self.buffer.get(self.batch_size):
                
                # Тело функции аналогично методу train в AverageReturnBaselineReinforce
                actions = batch_data.actions.long()
                policy_output = self.policy.evaluate_actions(batch_data.observations, actions)
                log_prob = policy_output['log_prob']
                entropy = policy_output['entropy']

                # Используем baseline, вычисленный для всей траектории
                returns = batch_data.returns - baseline # returns = Advantage

                # Policy gradient loss
                policy_loss = -(returns * log_prob).mean()

                # Entropy loss
                entropy = torch.mean(entropy)
                entropy_loss = -self.ent_coef * entropy

                loss = policy_loss + entropy_loss

                # Optimization step
                self.policy.optimizer.zero_grad()
                loss.backward()
                grad_norm = torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
                self.policy.optimizer.step()

                self._n_updates += 1
                
                # Сохраняем статистику этого батча
                all_policy_losses.append(policy_loss.item())
                all_entropies.append(entropy.item())
                all_entropy_losses.append(entropy_loss.item())
                all_losses.append(loss.item())
                all_grad_norms.append(grad_norm.item())

        # Логируем СРЕДНИЕ значения по всем батчам,
        # которые были обработаны за n_epochs
        self.log_dict = dict([
            ("train/entropy_loss", np.mean(all_entropy_losses)), 
            ("train/entropy", np.mean(all_entropies)),
            ("train/policy_gradient_loss", np.mean(all_policy_losses)), 
            ("train/loss", np.mean(all_losses)),
            ("train/grad_norm", np.mean(all_grad_norms)), 
            ("train/n_updates", self._n_updates),
            ("train/baseline", baseline)
        ])

# %% [markdown]
# ### Одна эпоха обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=1, device="cpu"),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-1', mode="offline"),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='./reinforce_batch-epoch-1')
)
# Out:
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cpu device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_4117/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_4117/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1276,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 425.3333333333333,
#     "rollout/ep_rew_mean": -101.22367095947266,
#     "time/fps": 311,
#     "time/iterations": 3,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.10327029208731234,
#     "train/entropy": 1.523536823320552e-11,
#     "train/entropy_loss": -1.523536901699334e-14,
#     "train/grad_norm": 7.40588825345629e-12,
#     "train/loss": -1.523536901699334e-14,
#     "train/n_updates": 13,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 2060,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -107.1285400390625,
#     "time/fps": 294,
#     "time/iterations": 5,
#     "time/time_elapsed": 6,
#     "train/baseline": -0.0803097057939177,
#     "train/entropy": 1.4997900274135723e-11,
#     "train/entropy_loss": -1.499790110676911e-14,
#     "train/grad_norm": 7.616705660282164e-12,
#     "train/loss": -1.499790110676911e-14,
#     "train/n_updates": 30,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 3394,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 424.25,
#     "rollout/ep_rew_mean": -110.45021057128906,
#     "time/fps": 293,
#     "time/iterations": 8,
#     "time/time_elapsed": 11,
#     "train/baseline": -0.09730778256133543,
#     "train/entropy": 1.7517973554894072e-11,
#     "train/entropy_loss": -1.7517974337068494e-14,
#     "train/grad_norm": 7.349850762727872e-12,
#     "train/loss": -1.7517974337068494e-14,
#     "train/n_updates": 50,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 4172,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 417.2,
#     "rollout/ep_rew_mean": -111.55440521240234,
#     "time/fps": 293,
#     "time/iterations": 10,
#     "time/time_elapsed": 14,
#     "train/baseline": -0.10050794332628896,
#     "train/entropy": 1.4003704337621492e-11,
#     "train/entropy_loss": -1.4003704972896202e-14,
#     "train/grad_norm": 4.305386559419477e-12,
#     "train/loss": -1.4003704972896202e-14,
#     "train/n_updates": 65,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 5277,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 400.1,
#     "rollout/ep_rew_mean": -115.9847412109375,
#     "time/fps": 291,
#     "time/iterations": 13,
#     "time/time_elapsed": 18,
#     "train/baseline": -0.10540354767400155,
#     "train/entropy": 1.642644477780778e-11,
#     "train/entropy_loss": -1.642644581360807e-14,
#     "train/grad_norm": 8.30351152419917e-12,
#     "train/loss": -1.642644581360807e-14,
#     "train/n_updates": 83,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 6056,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 399.6,
#     "rollout/ep_rew_mean": -115.98640441894531,
#     "time/fps": 289,
#     "time/iterations": 15,
#     "time/time_elapsed": 20,
#     "train/baseline": -0.10503281185326425,
#     "train/entropy": 1.4639514523468518e-11,
#     "train/entropy_loss": -1.463951521991783e-14,
#     "train/grad_norm": 4.762285473377166e-12,
#     "train/loss": -1.463951521991783e-14,
#     "train/n_updates": 98,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 7287,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 389.3,
#     "rollout/ep_rew_mean": -115.9886474609375,
#     "time/fps": 291,
#     "time/iterations": 18,
#     "time/time_elapsed": 25,
#     "train/baseline": -0.10890463163854779,
#     "train/entropy": 1.85866079471797e-11,
#     "train/entropy_loss": -1.8586608850681512e-14,
#     "train/grad_norm": 8.674937865849977e-12,
#     "train/loss": -1.8586608850681512e-14,
#     "train/n_updates": 117,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 8230,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 405.8,
#     "rollout/ep_rew_mean": -115.98929595947266,
#     "time/fps": 291,
#     "time/iterations": 20,
#     "time/time_elapsed": 28,
#     "train/baseline": -0.10787102286672341,
#     "train/entropy": 1.6558314615278125e-11,
#     "train/entropy_loss": -1.6558315331303308e-14,
#     "train/grad_norm": 4.408700191964803e-12,
#     "train/loss": -1.6558315331303308e-14,
#     "train/n_updates": 132,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 9340,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 406.3,
#     "rollout/ep_rew_mean": -115.98429107666016,
#     "time/fps": 289,
#     "time/iterations": 23,
#     "time/time_elapsed": 32,
#     "train/baseline": -0.10783721973219601,
#     "train/entropy": 1.526759656200749e-11,
#     "train/entropy_loss": -1.5267597773603418e-14,
#     "train/grad_norm": 1.318598563671003e-11,
#     "train/loss": -1.5267597773603418e-14,
#     "train/n_updates": 151,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 10380,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 432.4,
#     "rollout/ep_rew_mean": -115.9825668334961,
#     "time/fps": 291,
#     "time/iterations": 25,
#     "time/time_elapsed": 35,
#     "train/baseline": -0.10499688290666721,
#     "train/entropy": 1.6204647866613353e-11,
#     "train/entropy_loss": -1.6204648582638537e-14,
#     "train/grad_norm": 4.883156499720869e-12,
#     "train/loss": -1.6204648582638537e-14,
#     "train/n_updates": 167,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 11056,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 414.4,
#     "rollout/ep_rew_mean": -115.98072814941406,
#     "time/fps": 289,
#     "time/iterations": 27,
#     "time/time_elapsed": 38,
#     "train/baseline": -0.10481318714929462,
#     "train/entropy": 1.4981607389848623e-11,
#     "train/entropy_loss": -1.4981608110391318e-14,
#     "train/grad_norm": 8.697531844042983e-12,
#     "train/loss": -1.4981608110391318e-14,
#     "train/n_updates": 181,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 12189,
#     "num_episodes": 30,
#     "rollout/ep_len_mean": 395.9,
#     "rollout/ep_rew_mean": -115.98518371582031,
#     "time/fps": 291,
#     "time/iterations": 30,
#     "time/time_elapsed": 41,
#     "train/baseline": -0.10612754485896175,
#     "train/entropy": 1.6916488175533484e-11,
#     "train/entropy_loss": -1.691648914228042e-14,
#     "train/grad_norm": 1.1738387677961056e-11,
#     "train/loss": -1.691648914228042e-14,
#     "train/n_updates": 197,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 13149,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 380.9,
#     "rollout/ep_rew_mean": -115.988525390625,
#     "time/fps": 290,
#     "time/iterations": 33,
#     "time/time_elapsed": 45,
#     "train/baseline": -0.1094793162634311,
#     "train/entropy": 1.5928903161765984e-11,
#     "train/entropy_loss": -1.5928903863593283e-14,
#     "train/grad_norm": 5.143958609760135e-12,
#     "train/loss": -1.5928903863593283e-14,
#     "train/n_updates": 216,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 14292,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 358.4,
#     "rollout/ep_rew_mean": -115.9907455444336,
#     "time/fps": 277,
#     "time/iterations": 36,
#     "time/time_elapsed": 51,
#     "train/baseline": -0.11054868400868866,
#     "train/entropy": 1.735888680098268e-11,
#     "train/entropy_loss": -1.735888748613822e-14,
#     "train/grad_norm": 5.524084493269441e-12,
#     "train/loss": -1.735888748613822e-14,
#     "train/n_updates": 235,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 15008,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 370.3,
#     "rollout/ep_rew_mean": -115.9906997680664,
#     "time/fps": 269,
#     "time/iterations": 38,
#     "time/time_elapsed": 55,
#     "train/baseline": -0.11064810878407065,
#     "train/entropy": 1.556298777845498e-11,
#     "train/entropy_loss": -1.5562988655497094e-14,
#     "train/grad_norm": 5.9165388362401675e-12,
#     "train/loss": -1.5562988655497094e-14,
#     "train/n_updates": 248,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 16060,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 387.1,
#     "rollout/ep_rew_mean": -115.990234375,
#     "time/fps": 267,
#     "time/iterations": 40,
#     "time/time_elapsed": 60,
#     "train/baseline": -0.11063297308789664,
#     "train/entropy": 1.567521739338619e-11,
#     "train/entropy_loss": -1.5675218262253762e-14,
#     "train/grad_norm": 3.789854184720825e-12,
#     "train/loss": -1.5675218262253762e-14,
#     "train/n_updates": 262,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 17542,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 439.3,
#     "rollout/ep_rew_mean": -115.99095153808594,
#     "time/fps": 270,
#     "time/iterations": 43,
#     "time/time_elapsed": 64,
#     "train/baseline": -0.10958140121300768,
#     "train/entropy": 1.4347571493973049e-11,
#     "train/entropy_loss": -1.4347572246138305e-14,
#     "train/grad_norm": 6.140313394151617e-12,
#     "train/loss": -1.4347572246138305e-14,
#     "train/n_updates": 283,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 18405,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 446.6,
#     "rollout/ep_rew_mean": -115.9905014038086,
#     "time/fps": 271,
#     "time/iterations": 45,
#     "time/time_elapsed": 67,
#     "train/baseline": -0.10790282093457253,
#     "train/entropy": 1.451239432445628e-11,
#     "train/entropy_loss": -1.4512394915120587e-14,
#     "train/grad_norm": 7.621119591886641e-12,
#     "train/loss": -1.4512394915120587e-14,
#     "train/n_updates": 300,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 19022,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 430.0,
#     "rollout/ep_rew_mean": -115.99056243896484,
#     "time/fps": 271,
#     "time/iterations": 47,
#     "time/time_elapsed": 70,
#     "train/baseline": -0.10818145844299264,
#     "train/entropy": 1.456804798322109e-11,
#     "train/entropy_loss": -1.4568048339652553e-14,
#     "train/grad_norm": 1.034932781834863e-11,
#     "train/loss": -1.4568048339652553e-14,
#     "train/n_updates": 313,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 20337,
#     "num_episodes": 50,
#     "rollout/ep_len_mean": 427.7,
#     "rollout/ep_rew_mean": -115.99192810058594,
#     "time/fps": 273,
#     "time/iterations": 50,
#     "time/time_elapsed": 74,
#     "train/baseline": -0.10731334701732238,
#     "train/entropy": 1.3968729323045524e-11,
#     "train/entropy_loss": -1.3968730347229362e-14,
#     "train/grad_norm": 5.401736969430043e-12,
#     "train/loss": -1.3968730347229362e-14,
#     "train/n_updates": 333,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 21148,
#     "num_episodes": 52,
#     "rollout/ep_len_mean": 429.3,
#     "rollout/ep_rew_mean": -115.99351501464844,
#     "time/fps": 273,
#     "time/iterations": 52,
#     "time/time_elapsed": 77,
#     "train/baseline": -0.10662667172561135,
#     "train/entropy": 1.4525435433447587e-11,
#     "train/entropy_loss": -1.4525436293186028e-14,
#     "train/grad_norm": 6.23672028734687e-12,
#     "train/loss": -1.4525436293186028e-14,
#     "train/n_updates": 349,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 22472,
#     "num_episodes": 55,
#     "rollout/ep_len_mean": 406.7,
#     "rollout/ep_rew_mean": -115.98899841308594,
#     "time/fps": 275,
#     "time/iterations": 55,
#     "time/time_elapsed": 81,
#     "train/baseline": -0.1069553697587865,
#     "train/entropy": 1.4169899133022389e-11,
#     "train/entropy_loss": -1.4169899583159898e-14,
#     "train/grad_norm": 6.013749580159005e-12,
#     "train/loss": -1.4169899583159898e-14,
#     "train/n_updates": 367,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 23341,
#     "num_episodes": 57,
#     "rollout/ep_len_mean": 431.9,
#     "rollout/ep_rew_mean": -115.98832702636719,
#     "time/fps": 276,
#     "time/iterations": 57,
#     "time/time_elapsed": 84,
#     "train/baseline": -0.10709036659773327,
#     "train/entropy": 1.5961513361029134e-11,
#     "train/entropy_loss": -1.596151398670414e-14,
#     "train/grad_norm": 8.826845143116343e-12,
#     "train/loss": -1.596151398670414e-14,
#     "train/n_updates": 383,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 24195,
#     "num_episodes": 59,
#     "rollout/ep_len_mean": 433.4,
#     "rollout/ep_rew_mean": -115.9858627319336,
#     "time/fps": 276,
#     "time/iterations": 59,
#     "time/time_elapsed": 87,
#     "train/baseline": -0.10577747819131716,
#     "train/entropy": 1.3306192519352278e-11,
#     "train/entropy_loss": -1.330619303434831e-14,
#     "train/grad_norm": 6.247586974671149e-12,
#     "train/loss": -1.330619303434831e-14,
#     "train/n_updates": 400,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 25237,
#     "num_episodes": 61,
#     "rollout/ep_len_mean": 443.2,
#     "rollout/ep_rew_mean": -115.9862060546875,
#     "time/fps": 277,
#     "time/iterations": 61,
#     "time/time_elapsed": 90,
#     "train/baseline": -0.10568332117206723,
#     "train/entropy": 1.5620601552215587e-11,
#     "train/entropy_loss": -1.5620602424847752e-14,
#     "train/grad_norm": 5.032598975861687e-12,
#     "train/loss": -1.5620602424847752e-14,
#     "train/n_updates": 415,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 26111,
#     "num_episodes": 63,
#     "rollout/ep_len_mean": 467.8,
#     "rollout/ep_rew_mean": -115.9910888671875,
#     "time/fps": 277,
#     "time/iterations": 63,
#     "time/time_elapsed": 94,
#     "train/baseline": -0.10497413440776567,
#     "train/entropy": 1.529322881440448e-11,
#     "train/entropy_loss": -1.5293229519982925e-14,
#     "train/grad_norm": 6.013945146998018e-12,
#     "train/loss": -1.5293229519982925e-14,
#     "train/n_updates": 432,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 27352,
#     "num_episodes": 66,
#     "rollout/ep_len_mean": 455.8,
#     "rollout/ep_rew_mean": -115.9894027709961,
#     "time/fps": 278,
#     "time/iterations": 66,
#     "time/time_elapsed": 98,
#     "train/baseline": -0.10503904330980973,
#     "train/entropy": 1.571835052162814e-11,
#     "train/entropy_loss": -1.5718351156338163e-14,
#     "train/grad_norm": 8.32653636433552e-12,
#     "train/loss": -1.5718351156338163e-14,
#     "train/n_updates": 451,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 28219,
#     "num_episodes": 69,
#     "rollout/ep_len_mean": 402.4,
#     "rollout/ep_rew_mean": -115.98948669433594,
#     "time/fps": 278,
#     "time/iterations": 69,
#     "time/time_elapsed": 101,
#     "train/baseline": -0.10718698651329256,
#     "train/entropy": 1.2149743234060595e-11,
#     "train/entropy_loss": -1.2149743610143223e-14,
#     "train/grad_norm": 9.875027011385651e-12,
#     "train/loss": -1.2149743610143223e-14,
#     "train/n_updates": 467,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 29360,
#     "num_episodes": 72,
#     "rollout/ep_len_mean": 362.2,
#     "rollout/ep_rew_mean": -115.98939514160156,
#     "time/fps": 279,
#     "time/iterations": 72,
#     "time/time_elapsed": 105,
#     "train/baseline": -0.10878788327650815,
#     "train/entropy": 1.5608053189018294e-11,
#     "train/entropy_loss": -1.5608054055250653e-14,
#     "train/grad_norm": 6.989831601254363e-12,
#     "train/loss": -1.5608054055250653e-14,
#     "train/n_updates": 484,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 30204,
#     "num_episodes": 74,
#     "rollout/ep_len_mean": 368.7,
#     "rollout/ep_rew_mean": -115.98970794677734,
#     "time/fps": 279,
#     "time/iterations": 74,
#     "time/time_elapsed": 108,
#     "train/baseline": -0.1087550711921287,
#     "train/entropy": 1.620092653781269e-11,
#     "train/entropy_loss": -1.6200927115150345e-14,
#     "train/grad_norm": 1.4675289108923016e-11,
#     "train/loss": -1.6200927115150345e-14,
#     "train/n_updates": 498,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 31055,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 370.3,
#     "rollout/ep_rew_mean": -115.99173736572266,
#     "time/fps": 279,
#     "time/iterations": 76,
#     "time/time_elapsed": 111,
#     "train/baseline": -0.10734365307434056,
#     "train/entropy": 1.3527177352793776e-11,
#     "train/entropy_loss": -1.3527177906941553e-14,
#     "train/grad_norm": 4.021509205889531e-12,
#     "train/loss": -1.3527177906941553e-14,
#     "train/n_updates": 516,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 32181,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 396.2,
#     "rollout/ep_rew_mean": -115.992431640625,
#     "time/fps": 279,
#     "time/iterations": 79,
#     "time/time_elapsed": 114,
#     "train/baseline": -0.10700910952829232,
#     "train/entropy": 1.4286054853976778e-11,
#     "train/entropy_loss": -1.428605551030631e-14,
#     "train/grad_norm": 9.218410261326225e-12,
#     "train/loss": -1.428605551030631e-14,
#     "train/n_updates": 535,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 33019,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 421.3,
#     "rollout/ep_rew_mean": -115.992431640625,
#     "time/fps": 280,
#     "time/iterations": 81,
#     "time/time_elapsed": 117,
#     "train/baseline": -0.10730600887617896,
#     "train/entropy": 1.6522111555878586e-11,
#     "train/entropy_loss": -1.6522112376774518e-14,
#     "train/grad_norm": 7.632957014463188e-12,
#     "train/loss": -1.6522112376774518e-14,
#     "train/n_updates": 548,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 34340,
#     "num_episodes": 84,
#     "rollout/ep_len_mean": 413.6,
#     "rollout/ep_rew_mean": -115.9903335571289,
#     "time/fps": 281,
#     "time/iterations": 84,
#     "time/time_elapsed": 122,
#     "train/baseline": -0.10744090360553926,
#     "train/entropy": 1.6047091715327977e-11,
#     "train/entropy_loss": -1.6047092548808397e-14,
#     "train/grad_norm": 6.2197053605529684e-12,
#     "train/loss": -1.6047092548808397e-14,
#     "train/n_updates": 570,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 35116,
#     "num_episodes": 86,
#     "rollout/ep_len_mean": 406.1,
#     "rollout/ep_rew_mean": -115.989990234375,
#     "time/fps": 281,
#     "time/iterations": 86,
#     "time/time_elapsed": 124,
#     "train/baseline": -0.10704347120323116,
#     "train/entropy": 1.5125251125973945e-11,
#     "train/entropy_loss": -1.5125251829737318e-14,
#     "train/grad_norm": 7.627996882455683e-12,
#     "train/loss": -1.5125251829737318e-14,
#     "train/n_updates": 585,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 36143,
#     "num_episodes": 89,
#     "rollout/ep_len_mean": 396.2,
#     "rollout/ep_rew_mean": -115.9913558959961,
#     "time/fps": 281,
#     "time/iterations": 89,
#     "time/time_elapsed": 128,
#     "train/baseline": -0.10744040917539865,
#     "train/entropy": 1.292952059075055e-11,
#     "train/entropy_loss": -1.2929521294352585e-14,
#     "train/grad_norm": 8.392342521155541e-12,
#     "train/loss": -1.2929521294352585e-14,
#     "train/n_updates": 604,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 37314,
#     "num_episodes": 91,
#     "rollout/ep_len_mean": 429.5,
#     "rollout/ep_rew_mean": -115.99134826660156,
#     "time/fps": 281,
#     "time/iterations": 91,
#     "time/time_elapsed": 132,
#     "train/baseline": -0.10714341118911709,
#     "train/entropy": 1.5558038436840522e-11,
#     "train/entropy_loss": -1.5558039159641972e-14,
#     "train/grad_norm": 2.173168196615082e-12,
#     "train/loss": -1.5558039159641972e-14,
#     "train/n_updates": 622,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 38220,
#     "num_episodes": 93,
#     "rollout/ep_len_mean": 437.0,
#     "rollout/ep_rew_mean": -115.9891128540039,
#     "time/fps": 282,
#     "time/iterations": 93,
#     "time/time_elapsed": 135,
#     "train/baseline": -0.10683135582777069,
#     "train/entropy": 1.57723608479321e-11,
#     "train/entropy_loss": -1.5772361587028848e-14,
#     "train/grad_norm": 9.070403158720604e-12,
#     "train/loss": -1.5772361587028848e-14,
#     "train/n_updates": 636,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 39161,
#     "num_episodes": 95,
#     "rollout/ep_len_mean": 443.1,
#     "rollout/ep_rew_mean": -115.98786926269531,
#     "time/fps": 282,
#     "time/iterations": 95,
#     "time/time_elapsed": 138,
#     "train/baseline": -0.10609615012154998,
#     "train/entropy": 1.4531807378322734e-11,
#     "train/entropy_loss": -1.4531808088906374e-14,
#     "train/grad_norm": 2.6796086557820904e-12,
#     "train/loss": -1.4531808088906374e-14,
#     "train/n_updates": 656,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 40270,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 450.0,
#     "rollout/ep_rew_mean": -115.9848861694336,
#     "time/fps": 282,
#     "time/iterations": 98,
#     "time/time_elapsed": 142,
#     "train/baseline": -0.10672714108120386,
#     "train/entropy": 1.5138472217688752e-11,
#     "train/entropy_loss": -1.5138472824164343e-14,
#     "train/grad_norm": 8.496629181481419e-12,
#     "train/loss": -1.5138472824164343e-14,
#     "train/n_updates": 673,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 41411,
#     "num_episodes": 101,
#     "rollout/ep_len_mean": 409.7,
#     "rollout/ep_rew_mean": -115.98243713378906,
#     "time/fps": 282,
#     "time/iterations": 101,
#     "time/time_elapsed": 146,
#     "train/baseline": -0.10718803438062029,
#     "train/entropy": 1.4397817790431922e-11,
#     "train/entropy_loss": -1.4397818391825314e-14,
#     "train/grad_norm": 1.31769298163803e-11,
#     "train/loss": -1.4397818391825314e-14,
#     "train/n_updates": 691,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 42615,
#     "num_episodes": 104,
#     "rollout/ep_len_mean": 375.4,
#     "rollout/ep_rew_mean": -115.98503112792969,
#     "time/fps": 283,
#     "time/iterations": 104,
#     "time/time_elapsed": 150,
#     "train/baseline": -0.10791658019309919,
#     "train/entropy": 1.7211170683095745e-11,
#     "train/entropy_loss": -1.7211171114066107e-14,
#     "train/grad_norm": 1.2201144435064482e-11,
#     "train/loss": -1.7211171114066107e-14,
#     "train/n_updates": 709,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 43042,
#     "num_episodes": 105,
#     "rollout/ep_len_mean": 388.1,
#     "rollout/ep_rew_mean": -115.9867935180664,
#     "time/fps": 283,
#     "time/iterations": 105,
#     "time/time_elapsed": 152,
#     "train/baseline": -0.10778082097325378,
#     "train/entropy": 1.569417582003574e-11,
#     "train/entropy_loss": -1.569417661014807e-14,
#     "train/grad_norm": 3.525941084242534e-12,
#     "train/loss": -1.569417661014807e-14,
#     "train/n_updates": 719,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 44251,
#     "num_episodes": 108,
#     "rollout/ep_len_mean": 398.1,
#     "rollout/ep_rew_mean": -115.98747253417969,
#     "time/fps": 283,
#     "time/iterations": 108,
#     "time/time_elapsed": 156,
#     "train/baseline": -0.1075618356580882,
#     "train/entropy": 1.4144455861194357e-11,
#     "train/entropy_loss": -1.4144456649499686e-14,
#     "train/grad_norm": 9.463237485296538e-12,
#     "train/loss": -1.4144456649499686e-14,
#     "train/n_updates": 739,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 45411,
#     "num_episodes": 111,
#     "rollout/ep_len_mean": 400.0,
#     "rollout/ep_rew_mean": -115.98945617675781,
#     "time/fps": 283,
#     "time/iterations": 111,
#     "time/time_elapsed": 160,
#     "train/baseline": -0.10797387950110798,
#     "train/entropy": 1.675935293321551e-11,
#     "train/entropy_loss": -1.6759353406198707e-14,
#     "train/grad_norm": 1.1373291544658493e-11,
#     "train/loss": -1.6759353406198707e-14,
#     "train/n_updates": 758,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 46444,
#     "num_episodes": 113,
#     "rollout/ep_len_mean": 444.7,
#     "rollout/ep_rew_mean": -115.99095153808594,
#     "time/fps": 284,
#     "time/iterations": 113,
#     "time/time_elapsed": 163,
#     "train/baseline": -0.1078641200357247,
#     "train/entropy": 1.4946516246894248e-11,
#     "train/entropy_loss": -1.4946516987443052e-14,
#     "train/grad_norm": 8.534166429097212e-12,
#     "train/loss": -1.4946516987443052e-14,
#     "train/n_updates": 773,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 47245,
#     "num_episodes": 115,
#     "rollout/ep_len_mean": 420.3,
#     "rollout/ep_rew_mean": -115.98836517333984,
#     "time/fps": 284,
#     "time/iterations": 115,
#     "time/time_elapsed": 166,
#     "train/baseline": -0.10759398934486296,
#     "train/entropy": 1.5697386243860672e-11,
#     "train/entropy_loss": -1.56973868085493e-14,
#     "train/grad_norm": 9.316131561210953e-12,
#     "train/loss": -1.56973868085493e-14,
#     "train/n_updates": 789,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 48058,
#     "num_episodes": 117,
#     "rollout/ep_len_mean": 430.0,
#     "rollout/ep_rew_mean": -115.98884582519531,
#     "time/fps": 284,
#     "time/iterations": 117,
#     "time/time_elapsed": 168,
#     "train/baseline": -0.10723217314807967,
#     "train/entropy": 1.4123204713857783e-11,
#     "train/entropy_loss": -1.412320556089073e-14,
#     "train/grad_norm": 5.452236628448023e-12,
#     "train/loss": -1.412320556089073e-14,
#     "train/n_updates": 803,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 49169,
#     "num_episodes": 120,
#     "rollout/ep_len_mean": 426.7,
#     "rollout/ep_rew_mean": -115.9893798828125,
#     "time/fps": 284,
#     "time/iterations": 120,
#     "time/time_elapsed": 172,
#     "train/baseline": -0.10719145548576431,
#     "train/entropy": 1.6904824617682463e-11,
#     "train/entropy_loss": -1.6904825357424573e-14,
#     "train/grad_norm": 9.514866108548126e-12,
#     "train/loss": -1.6904825357424573e-14,
#     "train/n_updates": 822,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 50215,
#     "num_episodes": 123,
#     "rollout/ep_len_mean": 377.1,
#     "rollout/ep_rew_mean": -115.98681640625,
#     "time/fps": 285,
#     "time/iterations": 123,
#     "time/time_elapsed": 176,
#     "train/baseline": -0.10805976171406048,
#     "train/entropy": 1.693854041404097e-11,
#     "train/entropy_loss": -1.6938540939201397e-14,
#     "train/grad_norm": 1.1634653743902712e-11,
#     "train/loss": -1.6938540939201397e-14,
#     "train/n_updates": 839,
#     "train/policy_gradient_loss": 0.0
# }
# Задача не решена за 50000 шагов
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▄▅▅▄▃▄▄▆▅▂▁▂▃▆▆▅▆▄▆▆█▇▄▁▂▃▅▅▄▆▆▆▇▄▃▄▄▇▅</td></tr><tr><td>rollout/ep_rew_mean</td><td>█▅▄▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>█▅▅▅▅▅▅▅▅▅▃▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▃█▄▃▂▁▂▂▂▂▁▁▁▁▁▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>train/entropy</td><td>▄▄▇▃▆█▆▄▅▄▅▇▅▅▃▄▃▄▃▅▅▄▅▁▅▂▃▆▅▄▅▄▄▃▇▃▆▅▃▆</td></tr><tr><td>train/entropy_loss</td><td>▅▅▂▆▃▁▃▅▄▅▄▂▄▄▆▅▆▅▆▄▄▅▄█▄▇▆▃▄▅▄▄▅▅▆▆▃▄▆▃</td></tr><tr><td>train/grad_norm</td><td>▄▄▄▂▅▅▂█▂▅▃▃▃▂▃▆▃▃▃▅▃▃▅▆▄▂▅▄▃▄▅▁▅█▂▇▅▅▃▇</td></tr><tr><td>train/loss</td><td>▅▅▂▆▃▁▃▅▄▅▄▂▄▄▆▅▆▅▆▄▄▅▄█▄▆▃▄▅▇▄▅▅▆▂▃▅▄▆▃</td></tr><tr><td>train/n_updates</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>50215</td></tr><tr><td>num_episodes</td><td>123</td></tr><tr><td>rollout/ep_len_mean</td><td>377.1</td></tr><tr><td>rollout/ep_rew_mean</td><td>-115.98682</td></tr><tr><td>time/fps</td><td>285</td></tr><tr><td>time/iterations</td><td>123</td></tr><tr><td>time/time_elapsed</td><td>176</td></tr><tr><td>train/baseline</td><td>-0.10806</td></tr><tr><td>train/entropy</td><td>0.0</td></tr><tr><td>train/entropy_loss</td><td>-0.0</td></tr><tr><td>train/grad_norm</td><td>0.0</td></tr><tr><td>train/loss</td><td>-0.0</td></tr><tr><td>train/n_updates</td><td>839</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/RL/practices/prac5/wandb/offline-run-20251024_142244-7f1co6p7<code>
# Find logs at: <code>./wandb/offline-run-20251024_142244-7f1co6p7/logs</code>

# %% [markdown]
# ### Две эпохи обучения

# %%
run_algorithm(
    algorithm_class=BatchedAverageReturnReinforce,
    algorithm_kwargs=dict(seed=0, batch_size=64, n_epochs=2,  device="cpu"),
    use_wandb=True,
    wandb_kwargs=dict(project='seminar_actor-critic', monitor_gym=True, name='reinforce_batch-epoch-2', mode="offline"),
    learn_kwargs=dict(max_timesteps=50000, log_interval=1000, expected_return=2000, save_checkpoint_interval=1000,
                    save_checkpoint_path='./reinforce_batch-epoch-2')
)
# Out:
# /home/mitchell/dev/RL/venv/lib/python3.12/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# Using cpu device
# Tracking run with wandb version 0.19.1
# W&B syncing is set to <code>`offline`<code> in this directory.  <br>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /tmp/ipykernel_4117/3336005168.py:79: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(self._last_obs)
# /tmp/ipykernel_4117/3336005168.py:100: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   self._last_obs = np.array(new_obs)
# {
#     "global_step": 1276,
#     "num_episodes": 3,
#     "rollout/ep_len_mean": 425.3333333333333,
#     "rollout/ep_rew_mean": -101.22367095947266,
#     "time/fps": 275,
#     "time/iterations": 3,
#     "time/time_elapsed": 4,
#     "train/baseline": -0.10327029208731234,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 26,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 2060,
#     "num_episodes": 5,
#     "rollout/ep_len_mean": 412.0,
#     "rollout/ep_rew_mean": -107.1285400390625,
#     "time/fps": 249,
#     "time/iterations": 5,
#     "time/time_elapsed": 8,
#     "train/baseline": -0.0803097057939177,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 60,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 3394,
#     "num_episodes": 8,
#     "rollout/ep_len_mean": 424.25,
#     "rollout/ep_rew_mean": -110.45021057128906,
#     "time/fps": 250,
#     "time/iterations": 8,
#     "time/time_elapsed": 13,
#     "train/baseline": -0.09730778256133543,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 100,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 4172,
#     "num_episodes": 10,
#     "rollout/ep_len_mean": 417.2,
#     "rollout/ep_rew_mean": -111.55440521240234,
#     "time/fps": 245,
#     "time/iterations": 10,
#     "time/time_elapsed": 16,
#     "train/baseline": -0.10050794332628896,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 130,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 5277,
#     "num_episodes": 13,
#     "rollout/ep_len_mean": 400.1,
#     "rollout/ep_rew_mean": -115.9847412109375,
#     "time/fps": 245,
#     "time/iterations": 13,
#     "time/time_elapsed": 21,
#     "train/baseline": -0.10540354767400155,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 166,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 6056,
#     "num_episodes": 15,
#     "rollout/ep_len_mean": 399.6,
#     "rollout/ep_rew_mean": -115.98640441894531,
#     "time/fps": 244,
#     "time/iterations": 15,
#     "time/time_elapsed": 24,
#     "train/baseline": -0.10503281185326425,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 196,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 7287,
#     "num_episodes": 18,
#     "rollout/ep_len_mean": 389.3,
#     "rollout/ep_rew_mean": -115.9886474609375,
#     "time/fps": 245,
#     "time/iterations": 18,
#     "time/time_elapsed": 29,
#     "train/baseline": -0.10890463163854779,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 234,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 8230,
#     "num_episodes": 20,
#     "rollout/ep_len_mean": 405.8,
#     "rollout/ep_rew_mean": -115.98929595947266,
#     "time/fps": 245,
#     "time/iterations": 20,
#     "time/time_elapsed": 33,
#     "train/baseline": -0.10787102286672341,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 264,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 9340,
#     "num_episodes": 23,
#     "rollout/ep_len_mean": 406.3,
#     "rollout/ep_rew_mean": -115.98429107666016,
#     "time/fps": 245,
#     "time/iterations": 23,
#     "time/time_elapsed": 38,
#     "train/baseline": -0.10783721973219601,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 302,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 10380,
#     "num_episodes": 25,
#     "rollout/ep_len_mean": 432.4,
#     "rollout/ep_rew_mean": -115.9825668334961,
#     "time/fps": 245,
#     "time/iterations": 25,
#     "time/time_elapsed": 42,
#     "train/baseline": -0.10499688290666721,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 334,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 11056,
#     "num_episodes": 27,
#     "rollout/ep_len_mean": 414.4,
#     "rollout/ep_rew_mean": -115.98072814941406,
#     "time/fps": 244,
#     "time/iterations": 27,
#     "time/time_elapsed": 45,
#     "train/baseline": -0.10481318714929462,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 362,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 12189,
#     "num_episodes": 30,
#     "rollout/ep_len_mean": 395.9,
#     "rollout/ep_rew_mean": -115.98518371582031,
#     "time/fps": 245,
#     "time/iterations": 30,
#     "time/time_elapsed": 49,
#     "train/baseline": -0.10612754485896175,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 394,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 13149,
#     "num_episodes": 33,
#     "rollout/ep_len_mean": 380.9,
#     "rollout/ep_rew_mean": -115.988525390625,
#     "time/fps": 244,
#     "time/iterations": 33,
#     "time/time_elapsed": 53,
#     "train/baseline": -0.1094793162634311,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 432,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 14292,
#     "num_episodes": 36,
#     "rollout/ep_len_mean": 358.4,
#     "rollout/ep_rew_mean": -115.9907455444336,
#     "time/fps": 244,
#     "time/iterations": 36,
#     "time/time_elapsed": 58,
#     "train/baseline": -0.11054868400868866,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 470,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 15008,
#     "num_episodes": 38,
#     "rollout/ep_len_mean": 370.3,
#     "rollout/ep_rew_mean": -115.9906997680664,
#     "time/fps": 244,
#     "time/iterations": 38,
#     "time/time_elapsed": 61,
#     "train/baseline": -0.11064810878407065,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 496,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 16060,
#     "num_episodes": 40,
#     "rollout/ep_len_mean": 387.1,
#     "rollout/ep_rew_mean": -115.990234375,
#     "time/fps": 245,
#     "time/iterations": 40,
#     "time/time_elapsed": 65,
#     "train/baseline": -0.11063297308789664,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 524,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 17542,
#     "num_episodes": 43,
#     "rollout/ep_len_mean": 439.3,
#     "rollout/ep_rew_mean": -115.99095153808594,
#     "time/fps": 247,
#     "time/iterations": 43,
#     "time/time_elapsed": 71,
#     "train/baseline": -0.10958140121300768,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 566,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 18405,
#     "num_episodes": 45,
#     "rollout/ep_len_mean": 446.6,
#     "rollout/ep_rew_mean": -115.9905014038086,
#     "time/fps": 246,
#     "time/iterations": 45,
#     "time/time_elapsed": 74,
#     "train/baseline": -0.10790282093457253,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 600,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 19022,
#     "num_episodes": 47,
#     "rollout/ep_len_mean": 430.0,
#     "rollout/ep_rew_mean": -115.99056243896484,
#     "time/fps": 245,
#     "time/iterations": 47,
#     "time/time_elapsed": 77,
#     "train/baseline": -0.10818145844299264,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 626,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 20337,
#     "num_episodes": 50,
#     "rollout/ep_len_mean": 427.7,
#     "rollout/ep_rew_mean": -115.99192810058594,
#     "time/fps": 246,
#     "time/iterations": 50,
#     "time/time_elapsed": 82,
#     "train/baseline": -0.10731334701732238,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 666,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 21148,
#     "num_episodes": 52,
#     "rollout/ep_len_mean": 429.3,
#     "rollout/ep_rew_mean": -115.99351501464844,
#     "time/fps": 246,
#     "time/iterations": 52,
#     "time/time_elapsed": 85,
#     "train/baseline": -0.10662667172561135,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 698,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 22472,
#     "num_episodes": 55,
#     "rollout/ep_len_mean": 406.7,
#     "rollout/ep_rew_mean": -115.98899841308594,
#     "time/fps": 247,
#     "time/iterations": 55,
#     "time/time_elapsed": 90,
#     "train/baseline": -0.1069553697587865,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 734,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 23341,
#     "num_episodes": 57,
#     "rollout/ep_len_mean": 431.9,
#     "rollout/ep_rew_mean": -115.98832702636719,
#     "time/fps": 247,
#     "time/iterations": 57,
#     "time/time_elapsed": 94,
#     "train/baseline": -0.10709036659773327,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 766,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 24195,
#     "num_episodes": 59,
#     "rollout/ep_len_mean": 433.4,
#     "rollout/ep_rew_mean": -115.9858627319336,
#     "time/fps": 246,
#     "time/iterations": 59,
#     "time/time_elapsed": 98,
#     "train/baseline": -0.10577747819131716,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 800,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 25237,
#     "num_episodes": 61,
#     "rollout/ep_len_mean": 443.2,
#     "rollout/ep_rew_mean": -115.9862060546875,
#     "time/fps": 247,
#     "time/iterations": 61,
#     "time/time_elapsed": 102,
#     "train/baseline": -0.10568332117206723,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 830,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 26111,
#     "num_episodes": 63,
#     "rollout/ep_len_mean": 467.8,
#     "rollout/ep_rew_mean": -115.9910888671875,
#     "time/fps": 246,
#     "time/iterations": 63,
#     "time/time_elapsed": 105,
#     "train/baseline": -0.10497413440776567,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 864,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 27352,
#     "num_episodes": 66,
#     "rollout/ep_len_mean": 455.8,
#     "rollout/ep_rew_mean": -115.9894027709961,
#     "time/fps": 247,
#     "time/iterations": 66,
#     "time/time_elapsed": 110,
#     "train/baseline": -0.10503904330980973,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 902,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 28219,
#     "num_episodes": 69,
#     "rollout/ep_len_mean": 402.4,
#     "rollout/ep_rew_mean": -115.98948669433594,
#     "time/fps": 246,
#     "time/iterations": 69,
#     "time/time_elapsed": 114,
#     "train/baseline": -0.10718698651329256,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 934,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 29360,
#     "num_episodes": 72,
#     "rollout/ep_len_mean": 362.2,
#     "rollout/ep_rew_mean": -115.98939514160156,
#     "time/fps": 247,
#     "time/iterations": 72,
#     "time/time_elapsed": 118,
#     "train/baseline": -0.10878788327650815,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 968,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 30204,
#     "num_episodes": 74,
#     "rollout/ep_len_mean": 368.7,
#     "rollout/ep_rew_mean": -115.98970794677734,
#     "time/fps": 247,
#     "time/iterations": 74,
#     "time/time_elapsed": 122,
#     "train/baseline": -0.1087550711921287,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 996,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 31055,
#     "num_episodes": 76,
#     "rollout/ep_len_mean": 370.3,
#     "rollout/ep_rew_mean": -115.99173736572266,
#     "time/fps": 246,
#     "time/iterations": 76,
#     "time/time_elapsed": 125,
#     "train/baseline": -0.10734365307434056,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1032,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 32181,
#     "num_episodes": 79,
#     "rollout/ep_len_mean": 396.2,
#     "rollout/ep_rew_mean": -115.992431640625,
#     "time/fps": 246,
#     "time/iterations": 79,
#     "time/time_elapsed": 130,
#     "train/baseline": -0.10700910952829232,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1070,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 33019,
#     "num_episodes": 81,
#     "rollout/ep_len_mean": 421.3,
#     "rollout/ep_rew_mean": -115.992431640625,
#     "time/fps": 247,
#     "time/iterations": 81,
#     "time/time_elapsed": 133,
#     "train/baseline": -0.10730600887617896,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1096,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 34340,
#     "num_episodes": 84,
#     "rollout/ep_len_mean": 413.6,
#     "rollout/ep_rew_mean": -115.9903335571289,
#     "time/fps": 247,
#     "time/iterations": 84,
#     "time/time_elapsed": 138,
#     "train/baseline": -0.10744090360553926,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1140,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 35116,
#     "num_episodes": 86,
#     "rollout/ep_len_mean": 406.1,
#     "rollout/ep_rew_mean": -115.989990234375,
#     "time/fps": 247,
#     "time/iterations": 86,
#     "time/time_elapsed": 141,
#     "train/baseline": -0.10704347120323116,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1170,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 36143,
#     "num_episodes": 89,
#     "rollout/ep_len_mean": 396.2,
#     "rollout/ep_rew_mean": -115.9913558959961,
#     "time/fps": 247,
#     "time/iterations": 89,
#     "time/time_elapsed": 146,
#     "train/baseline": -0.10744040917539865,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1208,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 37314,
#     "num_episodes": 91,
#     "rollout/ep_len_mean": 429.5,
#     "rollout/ep_rew_mean": -115.99134826660156,
#     "time/fps": 247,
#     "time/iterations": 91,
#     "time/time_elapsed": 150,
#     "train/baseline": -0.10714341118911709,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1244,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 38220,
#     "num_episodes": 93,
#     "rollout/ep_len_mean": 437.0,
#     "rollout/ep_rew_mean": -115.9891128540039,
#     "time/fps": 247,
#     "time/iterations": 93,
#     "time/time_elapsed": 154,
#     "train/baseline": -0.10683135582777069,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1272,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 39161,
#     "num_episodes": 95,
#     "rollout/ep_len_mean": 443.1,
#     "rollout/ep_rew_mean": -115.98786926269531,
#     "time/fps": 247,
#     "time/iterations": 95,
#     "time/time_elapsed": 158,
#     "train/baseline": -0.10609615012154998,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1312,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 40270,
#     "num_episodes": 98,
#     "rollout/ep_len_mean": 450.0,
#     "rollout/ep_rew_mean": -115.9848861694336,
#     "time/fps": 247,
#     "time/iterations": 98,
#     "time/time_elapsed": 162,
#     "train/baseline": -0.10672714108120386,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1346,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 41411,
#     "num_episodes": 101,
#     "rollout/ep_len_mean": 409.7,
#     "rollout/ep_rew_mean": -115.98243713378906,
#     "time/fps": 247,
#     "time/iterations": 101,
#     "time/time_elapsed": 167,
#     "train/baseline": -0.10718803438062029,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1382,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 42615,
#     "num_episodes": 104,
#     "rollout/ep_len_mean": 375.4,
#     "rollout/ep_rew_mean": -115.98503112792969,
#     "time/fps": 248,
#     "time/iterations": 104,
#     "time/time_elapsed": 171,
#     "train/baseline": -0.10791658019309919,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1418,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 43042,
#     "num_episodes": 105,
#     "rollout/ep_len_mean": 388.1,
#     "rollout/ep_rew_mean": -115.9867935180664,
#     "time/fps": 247,
#     "time/iterations": 105,
#     "time/time_elapsed": 173,
#     "train/baseline": -0.10778082097325378,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1438,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 44251,
#     "num_episodes": 108,
#     "rollout/ep_len_mean": 398.1,
#     "rollout/ep_rew_mean": -115.98747253417969,
#     "time/fps": 247,
#     "time/iterations": 108,
#     "time/time_elapsed": 178,
#     "train/baseline": -0.1075618356580882,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1478,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 45411,
#     "num_episodes": 111,
#     "rollout/ep_len_mean": 400.0,
#     "rollout/ep_rew_mean": -115.98945617675781,
#     "time/fps": 247,
#     "time/iterations": 111,
#     "time/time_elapsed": 183,
#     "train/baseline": -0.10797387950110798,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1516,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 46444,
#     "num_episodes": 113,
#     "rollout/ep_len_mean": 444.7,
#     "rollout/ep_rew_mean": -115.99095153808594,
#     "time/fps": 248,
#     "time/iterations": 113,
#     "time/time_elapsed": 187,
#     "train/baseline": -0.1078641200357247,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1546,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 47245,
#     "num_episodes": 115,
#     "rollout/ep_len_mean": 420.3,
#     "rollout/ep_rew_mean": -115.98836517333984,
#     "time/fps": 247,
#     "time/iterations": 115,
#     "time/time_elapsed": 190,
#     "train/baseline": -0.10759398934486296,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1578,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 48058,
#     "num_episodes": 117,
#     "rollout/ep_len_mean": 430.0,
#     "rollout/ep_rew_mean": -115.98884582519531,
#     "time/fps": 247,
#     "time/iterations": 117,
#     "time/time_elapsed": 194,
#     "train/baseline": -0.10723217314807967,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1606,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 49169,
#     "num_episodes": 120,
#     "rollout/ep_len_mean": 426.7,
#     "rollout/ep_rew_mean": -115.9893798828125,
#     "time/fps": 247,
#     "time/iterations": 120,
#     "time/time_elapsed": 198,
#     "train/baseline": -0.10719145548576431,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1644,
#     "train/policy_gradient_loss": 0.0
# }
# {
#     "global_step": 50215,
#     "num_episodes": 123,
#     "rollout/ep_len_mean": 377.1,
#     "rollout/ep_rew_mean": -115.98681640625,
#     "time/fps": 247,
#     "time/iterations": 123,
#     "time/time_elapsed": 202,
#     "train/baseline": -0.10805976171406048,
#     "train/entropy": 0.0,
#     "train/entropy_loss": 0.0,
#     "train/grad_norm": 0.0,
#     "train/loss": 0.0,
#     "train/n_updates": 1678,
#     "train/policy_gradient_loss": 0.0
# }
# Задача не решена за 50000 шагов
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>num_episodes</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>rollout/ep_len_mean</td><td>▅▄▅▅▄▃▄▄▆▅▂▁▂▃▆▆▅▆▄▆▆█▇▁▂▃▅▅▄▃▆▆▇▄▂▄▇▅▆▂</td></tr><tr><td>rollout/ep_rew_mean</td><td>█▅▄▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time/fps</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▂▁▂▁▂▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>time/iterations</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>time/time_elapsed</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>train/baseline</td><td>▃█▄▃▂▂▂▂▂▂▁▁▁▁▂▂▂▂▂▂▂▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>train/entropy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/grad_norm</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/n_updates</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>global_step</td><td>50215</td></tr><tr><td>num_episodes</td><td>123</td></tr><tr><td>rollout/ep_len_mean</td><td>377.1</td></tr><tr><td>rollout/ep_rew_mean</td><td>-115.98682</td></tr><tr><td>time/fps</td><td>247</td></tr><tr><td>time/iterations</td><td>123</td></tr><tr><td>time/time_elapsed</td><td>202</td></tr><tr><td>train/baseline</td><td>-0.10806</td></tr><tr><td>train/entropy</td><td>0</td></tr><tr><td>train/entropy_loss</td><td>0</td></tr><tr><td>train/grad_norm</td><td>0</td></tr><tr><td>train/loss</td><td>0</td></tr><tr><td>train/n_updates</td><td>1678</td></tr><tr><td>train/policy_gradient_loss</td><td>0</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/mitchell/dev/RL/practices/prac5/wandb/offline-run-20251024_142542-2n9n9dij<code>
# Find logs at: <code>./wandb/offline-run-20251024_142542-2n9n9dij/logs</code>
